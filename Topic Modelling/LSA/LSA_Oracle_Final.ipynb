# %%
import pandas as pd

df = pd.read_csv(r'glassdoor_reviews.csv')

# %%
df
# Out:
#                          firm date_review                         job_title  \
# 0       AFH-Wealth-Management  2015-04-05
# 1       AFH-Wealth-Management  2015-12-11              Office Administrator
# 2       AFH-Wealth-Management  2016-01-28              Office Administrator
# 3       AFH-Wealth-Management  2016-04-16
# 4       AFH-Wealth-Management  2016-04-23              Office Administrator
# ...                       ...         ...                               ...
# 838561         the-LEGO-Group  2021-06-02                 Marketing Manager
# 838562         the-LEGO-Group  2021-06-03                   Sales Associate
# 838563         the-LEGO-Group  2021-06-03                        Strategist
# 838564         the-LEGO-Group  2021-06-04   Customer Service Representative
# 838565         the-LEGO-Group  2021-06-04        Human Resources Specialist
#
#                                     current  \
# 0                          Current Employee
# 1        Current Employee, more than 1 year
# 2        Current Employee, less than 1 year
# 3                          Current Employee
# 4        Current Employee, more than 1 year
# ...                                     ...
# 838561  Current Employee, more than 5 years
# 838562   Current Employee, less than 1 year
# 838563                     Current Employee
# 838564   Current Employee, less than 1 year
# 838565  Current Employee, more than 3 years
#
#                                           location  overall_rating  \
# 0                                              NaN               2
# 1                     Bromsgrove, England, England               2
# 2                     Bromsgrove, England, England               1
# 3                                              NaN               5
# 4                     Bromsgrove, England, England               1
# ...                                            ...             ...
# 838561                   München, Bavaria, Bavaria               5
# 838562                    London, England, England               3
# 838563                                         NaN               4
# 838564                                         NaN               5
# 838565  Kladno, Central Bohemian, Central Bohemian               5
#
#         work_life_balance  culture_values  diversity_inclusion  career_opp  \
# 0                     4.0             3.0                  NaN         2.0
# 1                     3.0             1.0                  NaN         2.0
# 2                     1.0             1.0                  NaN         1.0
# 3                     2.0             3.0                  NaN         2.0
# 4                     2.0             1.0                  NaN         2.0
# ...                   ...             ...                  ...         ...
# 838561                4.0             5.0                  4.0         4.0
# 838562                NaN             NaN                  NaN         NaN
# 838563                5.0             5.0                  5.0         3.0
# 838564                NaN             NaN                  NaN         NaN
# 838565                4.0             5.0                  4.0         4.0
#
#         comp_benefits  senior_mgmt recommend ceo_approv outlook  \
# 0                 3.0          3.0         x          o       r
# 1                 1.0          4.0         x          o       r
# 2                 1.0          1.0         x          o       x
# 3                 2.0          3.0         x          o       r
# 4                 1.0          1.0         x          o       x
# ...               ...          ...       ...        ...     ...
# 838561            4.0          4.0         v          v       v
# 838562            NaN          NaN         o          o       o
# 838563            5.0          3.0         v          o       o
# 838564            NaN          NaN         o          o       o
# 838565            5.0          5.0         v          v       o
#
#                                                headline  \
# 0               Young colleagues, poor micro management
# 1                          Excellent staff, poor salary
# 2                       Low salary, bad micromanagement
# 3                         Over promised under delivered
# 4                                client reporting admin
# ...                                                 ...
# 838561           Just an awesome company to work for!!!
# 838562                                  working at lego
# 838563           not interested in growing their people
# 838564                              Great Place to Work
# 838565  I strongly recommend the LEGO Group as employer
#
#                                                      pros  \
# 0       Very friendly and welcoming to new staff. Easy...
# 1           Friendly, helpful and hard-working colleagues
# 2       Easy to get the job even without experience in...
# 3                                 Nice staff to work with
# 4                   Easy to get the job, Nice colleagues.
# ...                                                   ...
# 838561  Great company values, awesome product, smart c...
# 838562                      staff discount is really nice
# 838563                    loved brand for a lot of people
# 838564          Good wages, good hours, lots of resources
# 838565  The LEGO Group is company with many opportunit...
#
#                                                      cons
# 0         Poor salaries, poor training and communication.
# 1       Poor salary which doesn't improve much with pr...
# 2       Very low salary, poor working conditions, very...
# 3                No career progression and salary is poor
# 4       Abysmal pay, around minimum wage. No actual tr...
# ...                                                   ...
# 838561       Not very easy to transfer to other locations
# 838562  micro managing is a hassle\r\ncan become menta...
# 838563  you can spend 6-10 years without any promotion...
# 838564  Working every other weekend, busy seasons can ...
# 838565  Many things are centralized in Denmark and rel...
#
# [838566 rows x 18 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pltss
import seaborn as sns
pd.set_option("display.max_colwidth", 200)

# %%
company_df = df[df['firm'] == 'Oracle']
company_df
# Out:
#           firm date_review                        job_title  \
# 615202  Oracle  2008-03-18             QA Software Engineer
# 615203  Oracle  2008-04-08    Senior Applications Engineer
# 615204  Oracle  2008-04-23                  Senior Director
# 615205  Oracle  2008-04-24       Principal Support Engineer
# 615206  Oracle  2008-05-04      Product Management Director
# ...        ...         ...                              ...
# 647138  Oracle  2021-06-05         Senior Software Engineer
# 647139  Oracle  2021-06-06                Senior Consultant
# 647140  Oracle  2021-06-06       Senior Engineering Manager
# 647141  Oracle  2021-06-06         Senior Software Engineer
# 647142  Oracle  2021-06-06                Software Engineer
#
#                                      current           location  \
# 615202                      Current Employee       San Jose, CA
# 615203                      Current Employee   Redwood City, CA
# 615204                      Current Employee  San Francisco, CA
# 615205                      Current Employee       New York, NY
# 615206                      Current Employee   Redwood City, CA
# ...                                      ...                ...
# 647138                       Former Employee                NaN
# 647139   Current Employee, more than 3 years                NaN
# 647140  Current Employee, more than 10 years          Bangalore
# 647141    Current Employee, more than 1 year          Bangalore
# 647142                      Current Employee          Hyderābād
#
#         overall_rating  work_life_balance  culture_values  \
# 615202               3                4.0             NaN
# 615203               4                4.0             NaN
# 615204               3                3.0             NaN
# 615205               4                5.0             NaN
# 615206               1                3.0             NaN
# ...                ...                ...             ...
# 647138               4                3.0             2.0
# 647139               4                5.0             5.0
# 647140               4                4.0             5.0
# 647141               4                5.0             5.0
# 647142               2                NaN             NaN
#
#         diversity_inclusion  career_opp  comp_benefits  senior_mgmt recommend  \
# 615202                  NaN         3.0            3.0          4.0         x
# 615203                  NaN         4.0            3.0          5.0         v
# 615204                  NaN         3.0            4.0          2.0         v
# 615205                  NaN         4.0            4.0          3.0         v
# 615206                  NaN         1.0            1.0          1.0         x
# ...                     ...         ...            ...          ...       ...
# 647138                  2.0         3.0            1.0          3.0         o
# 647139                  4.0         4.0            4.0          4.0         v
# 647140                  4.0         3.0            2.0          4.0         v
# 647141                  4.0         3.0            3.0          5.0         v
# 647142                  NaN         NaN            NaN          NaN         o
#
#        ceo_approv outlook  \
# 615202          r       o
# 615203          v       o
# 615204          v       o
# 615205          r       o
# 615206          x       o
# ...           ...     ...
# 647138          o       o
# 647139          v       v
# 647140          v       v
# 647141          v       v
# 647142          o       o
#
#                                                              headline  \
# 615202        Challenging, but many opportunity to learn and advance.
# 615203                               It is a job that pays the bills.
# 615204  Oracle - a good place to work, with some room for improvement
# 615205                                     It's ok to work at Oracle.
# 615206                                         Stay away from Oracle!
# ...                                                               ...
# 647138                                       Senior software engineer
# 647139                                      Nice company to work with
# 647140                                                         review
# 647141                                                 Company review
# 647142                                            Working with Oracle
#
#                                                                                                                                                                                                            pros  \
# 615202                                                                                Incredible opportunity for growth within company. You can learn a lot of technology from the sharp people that work here.
# 615203                                                                                       One of the best things about working here is the interaction with the customers. For me, that's the biggest "pro".
# 615204  Benefits - one of the most comprehensive benefits package in the industry\r\nRange of technologies - full spectrum of technologies is used at Oracle, including database, Java, web services, XML et...
# 615205                                                                                 Flexible work arrangements.  Equitable compensation package.  Recognition (by immediate management) for a job well done.
# 615206                                                                                            Oracle allows you to work from anywhere as long as you have an internet connection and access to a phone line
# ...                                                                                                                                                                                                         ...
# 647138                                                                                                                                                                              Good env to work in company
# 647139  Strong principles make great companies! Working for Oracle is like working in a family. Everyone shows empathy and supports in every situation. Lots of learning opportunities . work life balance ,...
# 647140                                                                                         Great Work Culture. Open culture to interact directly with stakeholders, greater visibility to higher management
# 647141                                                                                                                                                                          Great work place ,good learning
# 647142                                                                                                                                                             Decent salary, although there won't be hikes
#
#                                                                                                                                                                                                            cons
# 615202                                                                  There are too few employees. Often we have to switch our focus or job because there are not enough people. We are over-worked at times.
# 615203                                                                                  The fact that we have layoffs about every 2 years. The communication, people in the tech field don't seem to talk much.
# 615204  Too big at times - you have to deal with a number of different organizations to get your job done\r\nCan be bureaucratic - Oracle can lack the entrepreneurial spirit at times and there is an empha...
# 615205  I was part of the PeopleSoft takeover.  Oracle is certainly a bigger company and a great deal of the familial atmosphere that was inherent of PeopleSoft is definitely lost.  Albeit there is a reas...
# 615206                                                                                                                                                               There are many! slave labor comes to mind!
# ...                                                                                                                                                                                                         ...
# 647138                                                                                                                                                                               No benefits in the company
# 647139                                                                                                                                                                                     None. So far so good
# 647140                                                                                                                 Too much bounded by inhouse technologies. Very infrequent and very minimal salary raises
# 647141                                                                                                                                           Timings are not flexible,should focus on employee learning too
# 647142                                                          No work-life balance in certain teams/ divisions\r\nPolitics in certain teams/divisions\r\nNo hike/ bonuses\r\nNothing to motivate the employee
#
# [31941 rows x 18 columns]

# %%
len(company_df)
# Out:
# 31941

# %% [markdown]
# #  Pro

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\user\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\user\anaconda3\lib\site-packages (from gensim) (1.24.2)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\user\anaconda3\lib\site-packages (from gensim) (1.10.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\user\anaconda3\lib\site-packages (from gensim) (6.3.0)
# Requirement already satisfied: Cython==0.29.32 in c:\users\user\anaconda3\lib\site-packages (from gensim) (0.29.32)
# Requirement already satisfied: FuzzyTM>=0.4.0 in c:\users\user\anaconda3\lib\site-packages (from gensim) (2.0.5)
# Requirement already satisfied: pyfume in c:\users\user\anaconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim) (0.2.25)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim) (1.2.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\user\anaconda3\lib\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\user\anaconda3\lib\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->FuzzyTM>=0.4.0->gensim) (1.15.0)
# Requirement already satisfied: simpful in c:\users\user\anaconda3\lib\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.9.0)
# Requirement already satisfied: fst-pso in c:\users\user\anaconda3\lib\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: miniful in c:\users\user\anaconda3\lib\site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Requirement already satisfied: requests in c:\users\user\appdata\roaming\python\python38\site-packages (from simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.28.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2020.12.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\roaming\python\python38\site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (3.1.0)

# %%
import gensim
# Out:
# C:\Users\User\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
print(len(company_df['pros']))
print(len(company_df['cons']))
# Out:
# 31941
# 31941

# %%
#lowercasing 


pro_list = company_df['pros'].tolist()
import re
pro_lower_list = []
for review in pro_list:
    review = review.lower()
    pro_lower_list.append(review)

# %%
#Tokenisation
pro_tokenised_list = []
for review in pro_lower_list:
    pro_tokenised = review.split(" ")
    pro_tokenised_list.append(pro_tokenised)

# %%
#alphabetical
pro_words_only_list = []
for review in pro_tokenised_list:
    pro_words_only = [w for w in review if re.search('^[a-z]+$',w)]
    pro_words_only_list.append(pro_words_only)

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\user\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\anaconda3\lib\site-packages (from nltk) (2022.3.15)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\lib\site-packages (from nltk) (1.0.1)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from nltk) (4.59.0)
# Requirement already satisfied: click in c:\users\user\anaconda3\lib\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from click->nltk) (0.4.4)

# %%
import nltk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to C:\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#stop words
import nltk


from nltk.corpus import stopwords
pro_no_stop_words_list = []
stop_list = stopwords.words('english')
# Add extra words to the stop word list 

extra_stop_words = ['company','oracle','pros','cons'] #EDIT THIS PART
stop_list.extend(extra_stop_words)
for review in pro_words_only_list:
    pro_stop_removed = [w for w in review if w not in stop_list]
    pro_no_stop_words_list.append(pro_stop_removed)

# %%
# !pip install wordninja
# Out:
# Requirement already satisfied: wordninja in c:\users\user\anaconda3\lib\site-packages (2.0.0)

# %%
#to split conjoined words
import wordninja

import nltk

nltk.download('words')
english_words = set(nltk.corpus.words.words())



pro_no_combined_list = []

for review in pro_no_stop_words_list :
    new_review = []
    for word in review:
        if word not in english_words:
            word_split_list = wordninja.split(word)
            for w in word_split_list:
                new_review.append(w)
            
        new_review.append(word)
    
    pro_no_combined_list.append(new_review)
# Out:
# [nltk_data] Downloading package words to C:\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
print(len(pro_no_stop_words_list))
print(len(pro_no_combined_list))
# Out:
# 31941
# 31941

# %%
pro_adj_removed_list = []
for review in pro_no_combined_list:
    review_tagged_words = nltk.pos_tag(review)
#     print(review_tagged_words)
    review_adj_removed = [word for word, pos in review_tagged_words if pos.startswith('N')]
    pro_adj_removed_list.append(review_adj_removed)
#     print(pro_adj_removed_list[0:30])
len(pro_adj_removed_list)
# Out:
# 31941

# %% [markdown]
# # Cons

# %%
#lowercasing

con_list = company_df['cons'].tolist()
import re
con_lower_list = []
for review in con_list:
    review = review.lower()
    con_lower_list.append(review)

# %%
#Tokenisation
con_tokenised_list = []
for review in con_lower_list:
    con_tokenised = review.split(" ")
    con_tokenised_list.append(con_tokenised)
con_tokenised_list
# Out:
# [['there',
#   'are',
#   'too',
#   'few',
#   'employees.',
#   'often',
#   'we',
#   'have',
#   'to',
#   'switch',
#   'our',
#   'focus',
#   'or',
#   'job',
#   'because',
#   'there',
#   'are',
#   'not',
#   'enough',
#   'people.',
#   'we',
#   'are',
#   'over-worked',
#   'at',
#   'times.'],
#  ['the',
#   'fact',
#   'that',
#   'we',
#   'have',
#   'layoffs',
#   'about',
#   'every',
#   '2',
#   'years.',
#   'the',
#   'communication,',
#   'people',
#   'in',
#   'the',
#   'tech',
#   'field',
#   "don't",
#   'seem',
#   'to',
#   'talk',
#   'much.'],
#  ['too',
#   'big',
#   'at',
#   'times',
#   '-',
#   'you',
#   'have',
#   'to',
#   'deal',
#   'with',
#   'a',
#   'number',
#   'of',
#   'different',
#   'organizations',
#   'to',
#   'get',
#   'your',
#   'job',
#   'done\r\ncan',
#   'be',
#   'bureaucratic',
#   '-',
#   'oracle',
#   'can',
#   'lack',
#   'the',
#   'entrepreneurial',
#   'spirit',
#   'at',
#   'times',
#   'and',
#   'there',
#   'is',
#   'an',
#   'emphasis',
#   'on',
#   'doing',
#   'things',
#   '"by',
#   'the',
#   'book"\r\nnot',
#   'the',
#   'best',
#   'paymaster',
#   '-',
#   'base',
#   'pay',
#   'is',
#   'middle',
#   'of',
#   'the',
#   'road,',
#   'and',
#   'equity',
#   'at',
#   'lower',
#   'levels',
#   'in',
#   'the',
#   'organization',
#   'is',
#   'non-existent.'],
#  ['i',
#   'was',
#   'part',
#   'of',
#   'the',
#   'peoplesoft',
#   'takeover.',
#   '',
#   'oracle',
#   'is',
#   'certainly',
#   'a',
#   'bigger',
#   'company',
#   'and',
#   'a',
#   'great',
#   'deal',
#   'of',
#   'the',
#   'familial',
#   'atmosphere',
#   'that',
#   'was',
#   'inherent',
#   'of',
#   'peoplesoft',
#   'is',
#   'definitely',
#   'lost.',
#   '',
#   'albeit',
#   'there',
#   'is',
#   'a',
#   'reason',
#   'mr.',
#   'ellison',
#   'makes',
#   'the',
#   'money',
#   'he',
#   'does',
#   'and',
#   'surely',
#   'i',
#   'represent',
#   'just',
#   'a',
#   'small',
#   'part',
#   'of',
#   'his',
#   'employee',
#   'population.',
#   '',
#   'it',
#   'appears',
#   'though,',
#   'that',
#   'executive',
#   'management',
#   'at',
#   'peoplesoft',
#   'had',
#   'a',
#   'better',
#   'knack',
#   'for',
#   'understanding',
#   'what',
#   'we,',
#   'who',
#   'are',
#   'on',
#   'the',
#   'front/first',
#   'line',
#   'of',
#   "''combat''",
#   'with',
#   'the',
#   'clients,',
#   'go',
#   'through.',
#   '',
#   'changes',
#   'were',
#   'instituted',
#   'with',
#   'both',
#   'the',
#   'client',
#   'and',
#   'us,',
#   'in',
#   'mind.'],
#  ['there', 'are', 'many!', 'slave', 'labor', 'comes', 'to', 'mind!'],
#  ['large',
#   'companies',
#   'tend',
#   'to',
#   'lose',
#   'track',
#   'of',
#   'individuals',
#   'unless',
#   'they',
#   'promote',
#   'themselves',
#   'aggressively.',
#   '',
#   'and',
#   'of',
#   'course',
#   'there',
#   'is',
#   'fierce',
#   'competition',
#   'for',
#   'finite',
#   'resources',
#   'such',
#   'as',
#   'bonus',
#   'and',
#   'stock',
#   'pools,',
#   'title',
#   'advancement,',
#   'and',
#   'recognition',
#   'awards.',
#   '',
#   'making',
#   'it',
#   'to',
#   '"sales',
#   'club"',
#   'as',
#   'a',
#   'sales',
#   'consultant',
#   'is',
#   'next',
#   'to',
#   'impossible,',
#   'given',
#   'that',
#   'very',
#   'few',
#   'slots',
#   'are',
#   'awarded',
#   'outside',
#   'those',
#   'who',
#   'carry',
#   'actual',
#   'quotas.',
#   '',
#   'benefits',
#   'and',
#   'perks',
#   'have',
#   'been',
#   'scaling',
#   'back',
#   'ever',
#   'so',
#   'gradually',
#   'over',
#   'the',
#   'past',
#   'few',
#   'years',
#   'for',
#   'scs;',
#   'travel',
#   'has',
#   'been',
#   'scaled',
#   'back,',
#   'cubicle',
#   'hotelling',
#   'has',
#   'swept',
#   'the',
#   'organization,',
#   'and',
#   'so',
#   'forth,',
#   'while',
#   'management',
#   'strives',
#   'to',
#   'wring',
#   'every',
#   'ounce',
#   'of',
#   'productivity',
#   'out',
#   'of',
#   'the',
#   'sales',
#   'organization.'],
#  ['while',
#   'oracle',
#   'management',
#   'provides',
#   'plenty',
#   'of',
#   'benefits,',
#   'recognition,',
#   'support,',
#   'flexible',
#   'hours,',
#   'and',
#   'stock',
#   'options,',
#   'it',
#   'remains',
#   'very',
#   'difficult',
#   'to',
#   'get',
#   'raises',
#   '--',
#   'even',
#   'small',
#   'cost-of-living',
#   'raises.',
#   'one',
#   'of',
#   'my',
#   'colleagues',
#   'has',
#   'worked',
#   'here',
#   'for',
#   'six',
#   'years',
#   'without',
#   'a',
#   'raise.',
#   '',
#   'the',
#   'lack',
#   'of',
#   'raises',
#   'has',
#   'the',
#   'negative',
#   'effect',
#   'of',
#   'causing',
#   'a',
#   'lot',
#   'of',
#   'people',
#   'to',
#   'leave',
#   'oracle',
#   'for',
#   'more',
#   'lucrative',
#   'positions,',
#   'which,',
#   'in',
#   'turn',
#   'causes',
#   'everyone',
#   'else',
#   'to',
#   'have',
#   'to',
#   'spend',
#   'a',
#   'lot',
#   'of',
#   'time',
#   'interviewing',
#   'new',
#   'job',
#   'applicants.',
#   '',
#   'also,',
#   'because',
#   'the',
#   'nature',
#   'of',
#   'the',
#   'technology',
#   'industry',
#   'is',
#   'so',
#   'complex,',
#   'new',
#   'people',
#   'require',
#   'a',
#   'tremendous',
#   'amount',
#   'of',
#   'time',
#   'to',
#   'come',
#   'up',
#   'to',
#   'speed',
#   'on',
#   'both',
#   'internal',
#   'tools',
#   'and',
#   'systems',
#   'as',
#   'well',
#   'as',
#   'business',
#   'practices.'],
#  ['career',
#   'growth',
#   'limited',
#   ',',
#   'compensation',
#   'is',
#   'not',
#   'very',
#   'performance',
#   'driven.'],
#  ['bad', 'compensation,', 'used', 'to', 'easy', 'going', 'life'],
#  ['sometimes',
#   'it',
#   'takes',
#   'along',
#   'time',
#   'for',
#   'management',
#   'to',
#   'approve',
#   'certain',
#   'things',
#   'but',
#   'with',
#   'the',
#   'state',
#   'of',
#   'the',
#   'economy',
#   'today',
#   'and',
#   'right',
#   'now',
#   'i',
#   'am',
#   'sure',
#   'that',
#   'has',
#   'alot',
#   'to',
#   'do',
#   'with',
#   'them',
#   'being',
#   'cautious',
#   'about',
#   'spending',
#   'and',
#   'budgets',
#   'at',
#   'the',
#   'moment.',
#   'i',
#   'also',
#   'think',
#   'that',
#   'sometimes',
#   'things',
#   'are',
#   'done',
#   'a',
#   'little',
#   'backwards,',
#   'but',
#   'when',
#   'you',
#   'own',
#   'a',
#   'big',
#   'corporation',
#   'you',
#   'need',
#   'to',
#   'make',
#   'the',
#   'decisions',
#   'that',
#   'are',
#   'best',
#   'suited',
#   'for',
#   'everyone',
#   'involved'],
#  ['oracle',
#   'has',
#   'a',
#   'top',
#   'down',
#   'management',
#   'style.',
#   'all',
#   'the',
#   'ideation',
#   'and',
#   'strategy',
#   'is',
#   'driven',
#   'by',
#   'top',
#   'management.',
#   'it',
#   'is',
#   'very',
#   'hard',
#   'to',
#   'get',
#   'recognized',
#   'at',
#   'this',
#   'big',
#   'company.',
#   'some',
#   'managers',
#   'are',
#   'nice',
#   'while',
#   'others',
#   'are',
#   'outright',
#   'disrespectful',
#   'and',
#   'mean.',
#   'its',
#   'a',
#   'mix.'],
#  ['high',
#   'stress',
#   'environment,',
#   'lack',
#   'of',
#   'resources,',
#   'low',
#   'compensation',
#   'compared',
#   'to',
#   'industry',
#   'standards,',
#   'lack',
#   'of',
#   'communication',
#   'of',
#   'key',
#   'issues',
#   'from',
#   'upper',
#   'management'],
#  ['salary',
#   'and',
#   'job',
#   'advancement.',
#   'very',
#   'top',
#   'down',
#   'type',
#   'of',
#   'organization.'],
#  ['employees',
#   'seem',
#   'to',
#   'be',
#   'promoted',
#   'based',
#   'on',
#   'relationships',
#   'and',
#   'favoritism',
#   'instead',
#   'of',
#   'merit.',
#   'overall',
#   'compensation',
#   'is',
#   'poor,',
#   'the',
#   'impression',
#   'of',
#   'most',
#   'employees',
#   'is',
#   'that',
#   'compensation',
#   'is',
#   'feast',
#   'or',
#   'famine,',
#   'with',
#   'a',
#   'small',
#   'number',
#   'of',
#   'employees',
#   'receiving',
#   'a',
#   'majority',
#   'of',
#   'the',
#   'compensation',
#   'pool',
#   'and',
#   'most',
#   'of',
#   'the',
#   'employees',
#   'living',
#   'on',
#   'hope.'],
#  ['employees',
#   'seem',
#   'to',
#   'be',
#   'promoted',
#   'based',
#   'on',
#   'relationships',
#   'and',
#   'favoritism',
#   'instead',
#   'of',
#   'merit.',
#   'overall',
#   'compensation',
#   'is',
#   'poor,',
#   'the',
#   'impression',
#   'of',
#   'most',
#   'employees',
#   'is',
#   'that',
#   'compensation',
#   'is',
#   'feast',
#   'or',
#   'famine,',
#   'with',
#   'a',
#   'small',
#   'number',
#   'of',
#   'employees',
#   'receiving',
#   'a',
#   'majority',
#   'of',
#   'the',
#   'compensation',
#   'pool',
#   'and',
#   'most',
#   'of',
#   'the',
#   'employees',
#   'living',
#   'on',
#   'hope.'],
#  ['very', 'few', 'parties', 'are', 'conducted'],
#  ['growth',
#   '(in',
#   'terms',
#   'of',
#   'promotions,',
#   'etc)',
#   'depends',
#   'on',
#   'the',
#   'team/project',
#   'you',
#   'work',
#   'on\r\nthere',
#   'is',
#   'no',
#   'single',
#   'direction',
#   '-',
#   'the',
#   'major',
#   'development',
#   'divisions',
#   'are',
#   'split',
#   'in',
#   'their',
#   'directions',
#   'and',
#   'are',
#   'often',
#   'at',
#   'odds',
#   'with',
#   'each',
#   'other'],
#  ['typical',
#   'big',
#   'company',
#   'problems,',
#   'group',
#   'politics,',
#   'some',
#   "group's",
#   'management',
#   'are',
#   'very',
#   'bad.'],
#  ['large',
#   'stable',
#   'company,',
#   'and',
#   "it's",
#   'becoming',
#   'like',
#   'ibm.',
#   'a',
#   'conglomerate',
#   'of',
#   'bureaucrats,',
#   'and',
#   'middle',
#   'managers.',
#   "don't",
#   'hold',
#   'your',
#   'breath',
#   'about',
#   'your',
#   'pet',
#   'projects',
#   'however.',
#   'lots',
#   'of',
#   'oldies',
#   'with',
#   'large',
#   'fragile',
#   "ego's",
#   'over',
#   'a',
#   'facade',
#   'of',
#   'arrogance',
#   'and',
#   'entitlement',
#   'all',
#   'over',
#   'the',
#   'place.'],
#  ['1.',
#   'money!',
#   'money!',
#   'money!',
#   'oracle',
#   'is',
#   'not',
#   'competitive',
#   'when',
#   'it',
#   'comes',
#   'to',
#   'salary.',
#   'the',
#   'start',
#   'salary',
#   'is',
#   'good,',
#   'but',
#   'the',
#   'recent',
#   'spate',
#   'of',
#   'acquisitions',
#   'has',
#   'not',
#   'left',
#   'any',
#   'money',
#   'to',
#   'be',
#   'offered',
#   'for',
#   'a',
#   'pay-hike',
#   'to',
#   'almost',
#   'everybody.\r\n2.',
#   'the',
#   'work',
#   'experience',
#   'is',
#   'not',
#   'been',
#   'taken',
#   'as',
#   'a',
#   'metric',
#   'while',
#   'offering',
#   'renewed',
#   'compensations.',
#   'the',
#   'new',
#   'guys',
#   'are',
#   'worth',
#   'lot,',
#   'but',
#   'the',
#   'people',
#   'already',
#   'in',
#   'the',
#   'company',
#   'are',
#   'being',
#   'ignored.'],
#  ['ruthless,',
#   'take',
#   'no',
#   'prisoners',
#   'culture.',
#   'willing',
#   'to',
#   'do',
#   'anything',
#   'for',
#   'enough',
#   'money.'],
#  ['ruthless,',
#   'take',
#   'no',
#   'prisoners',
#   'culture.',
#   'willing',
#   'to',
#   'do',
#   'anything',
#   'for',
#   'enough',
#   'money.'],
#  ['too', 'big.', '', 'internal', 'processes', 'are', 'archaic.'],
#  ['way', 'to', 'much', 'travel', 'you', 'are', 'really', 'on', 'your', 'own.'],
#  ['you',
#   'can',
#   'easily',
#   'be',
#   'overlooked.',
#   'the',
#   'different',
#   'cultures',
#   'here',
#   '@',
#   'oracle',
#   "don't",
#   'always',
#   'mesh',
#   'so',
#   'well.',
#   'as',
#   'much',
#   'as',
#   'we',
#   'would',
#   'want',
#   'them',
#   'to,',
#   'it',
#   'is',
#   'just',
#   'reality.'],
#  ['you',
#   'can',
#   'easily',
#   'be',
#   'overlooked.',
#   'the',
#   'different',
#   'cultures',
#   'here',
#   '@',
#   'oracle',
#   "don't",
#   'always',
#   'mesh',
#   'so',
#   'well.',
#   'as',
#   'much',
#   'as',
#   'we',
#   'would',
#   'want',
#   'them',
#   'to,',
#   'it',
#   'is',
#   'just',
#   'reality.'],
#  ['you',
#   'can',
#   'get',
#   'lost',
#   'in',
#   'such',
#   'a',
#   'large',
#   'company.',
#   '',
#   'many',
#   'times',
#   'performance',
#   'varies',
#   'between',
#   'the',
#   'groups',
#   'within',
#   'consulting,',
#   'but',
#   'bonuses',
#   'are',
#   'calculated',
#   'on',
#   'performance',
#   'of',
#   'all',
#   'groups',
#   'across',
#   'north',
#   'america.',
#   '',
#   'less',
#   'risk,',
#   'but',
#   'less',
#   'reward.'],
#  ['it', 'moves', 'slow', 'at', 'times'],
#  ['little',
#   'growth',
#   'opportunity',
#   'in',
#   'carrier.',
#   '\r\nyou',
#   'would',
#   'have',
#   'to',
#   'work',
#   'very',
#   'very',
#   'hard',
#   'to',
#   'move',
#   'forward.\r\ntypical',
#   'big',
#   'company.'],
#  ['little',
#   'growth',
#   'opportunity',
#   'in',
#   'carrier.',
#   '\r\nyou',
#   'would',
#   'have',
#   'to',
#   'work',
#   'very',
#   'very',
#   'hard',
#   'to',
#   'move',
#   'forward.\r\ntypical',
#   'big',
#   'company.'],
#  ['downsides', 'of', 'any', 'huge', 'company.'],
#  ['larry',
#   'ellison',
#   'has',
#   'basically',
#   "'managed",
#   "contempt'",
#   'for',
#   'sales',
#   '&',
#   'marketing,',
#   'read',
#   'any',
#   'of',
#   'the',
#   'books',
#   'to',
#   'understand',
#   'why',
#   'he',
#   'considers',
#   'sales',
#   '&',
#   'marketing',
#   'an',
#   'unnecessary',
#   'overhead,',
#   'and',
#   'only',
#   'select',
#   'engineering',
#   'divisions',
#   'the',
#   'heroes',
#   'of',
#   'the',
#   'company.',
#   'oracle',
#   'is',
#   'famous',
#   'for',
#   'the',
#   "'2",
#   "strikes'",
#   'hr',
#   'rule,',
#   'you',
#   'can',
#   'only',
#   'leave',
#   'twice,',
#   'and',
#   'once',
#   'one',
#   'internal',
#   'recruiter',
#   'contacts',
#   'you',
#   'about',
#   'a',
#   'job,',
#   'another',
#   'oracle',
#   'recruiter',
#   "can't",
#   'touch',
#   'you',
#   'till',
#   'you',
#   'pass',
#   'on',
#   'it',
#   'least',
#   'it',
#   'works',
#   'in',
#   'your',
#   'favor',
#   'for',
#   'a',
#   "'bidding",
#   "war'",
#   'between',
#   'departments.',
#   'yes,',
#   'oracle',
#   'is',
#   'pretty',
#   'much',
#   'entirely',
#   'unilateral.',
#   "'if",
#   "you're",
#   'not',
#   'happy',
#   'here,',
#   'how',
#   'soon',
#   'can',
#   'we',
#   'make',
#   'you',
#   'leave',
#   "?'"],
#  ['top', 'heavy', 'management', 'structure.', '', 'terrible', 'bureaucracy.'],
#  ['oracle',
#   'is',
#   'not',
#   'a',
#   'work-life',
#   'balance',
#   'place.',
#   '',
#   'plan',
#   'on',
#   'working',
#   'non-stop',
#   'while',
#   'you',
#   'are',
#   'there',
#   '-',
#   'that',
#   'is',
#   'both',
#   'a',
#   'strength',
#   'and',
#   'a',
#   'weakness',
#   'of',
#   'the',
#   'company.',
#   '',
#   'typically',
#   'they',
#   'give',
#   '2-3',
#   'people',
#   'the',
#   'same',
#   'job',
#   'and',
#   'see',
#   'who',
#   'is',
#   'standing',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'quarter.',
#   '',
#   'the',
#   'person',
#   'standing',
#   'gets',
#   'to',
#   'keep',
#   'the',
#   'job',
#   'for',
#   'the',
#   'next',
#   'quarter.',
#   '',
#   'in',
#   'addition,',
#   'the',
#   'ethics',
#   'of',
#   'this',
#   'organization',
#   'are',
#   'both',
#   'good',
#   'in',
#   'pockets',
#   'and',
#   'tremendously',
#   'bad.',
#   '',
#   'there',
#   'are',
#   'managers',
#   'on',
#   'the',
#   'government',
#   'side',
#   'doing',
#   'business',
#   'in',
#   'such',
#   'a',
#   'manner',
#   'as',
#   'to',
#   'be',
#   'shocking.',
#   '',
#   'if',
#   'you',
#   'want',
#   'to',
#   'have',
#   'an',
#   'ethical',
#   'compass,',
#   'i',
#   'would',
#   'make',
#   'sure',
#   'you',
#   'have',
#   'it',
#   'well',
#   'in',
#   'place',
#   'before',
#   'you',
#   'work',
#   'at',
#   'oracle.'],
#  ['oracle',
#   'is',
#   'not',
#   'a',
#   'work-life',
#   'balance',
#   'place.',
#   '',
#   'plan',
#   'on',
#   'working',
#   'non-stop',
#   'while',
#   'you',
#   'are',
#   'there',
#   '-',
#   'that',
#   'is',
#   'both',
#   'a',
#   'strength',
#   'and',
#   'a',
#   'weakness',
#   'of',
#   'the',
#   'company.',
#   '',
#   'typically',
#   'they',
#   'give',
#   '2-3',
#   'people',
#   'the',
#   'same',
#   'job',
#   'and',
#   'see',
#   'who',
#   'is',
#   'standing',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'quarter.',
#   '',
#   'the',
#   'person',
#   'standing',
#   'gets',
#   'to',
#   'keep',
#   'the',
#   'job',
#   'for',
#   'the',
#   'next',
#   'quarter.',
#   '',
#   'in',
#   'addition,',
#   'the',
#   'ethics',
#   'of',
#   'this',
#   'organization',
#   'are',
#   'both',
#   'good',
#   'in',
#   'pockets',
#   'and',
#   'tremendously',
#   'bad.',
#   '',
#   'there',
#   'are',
#   'managers',
#   'on',
#   'the',
#   'government',
#   'side',
#   'doing',
#   'business',
#   'in',
#   'such',
#   'a',
#   'manner',
#   'as',
#   'to',
#   'be',
#   'shocking.',
#   '',
#   'if',
#   'you',
#   'want',
#   'to',
#   'have',
#   'an',
#   'ethical',
#   'compass,',
#   'i',
#   'would',
#   'make',
#   'sure',
#   'you',
#   'have',
#   'it',
#   'well',
#   'in',
#   'place',
#   'before',
#   'you',
#   'work',
#   'at',
#   'oracle.'],
#  ['large', 'company', 'beaurocracy,', 'lot', 'of', 'politics'],
#  ['there',
#   "aren't",
#   'enough',
#   'innovative',
#   'products',
#   'to',
#   'work',
#   'on.',
#   'enterprise',
#   'applications',
#   'are',
#   'catching',
#   'up',
#   'to',
#   'consumer',
#   'applications',
#   '(web',
#   '2.0,',
#   'etc).',
#   'there',
#   "aren't",
#   'enough',
#   'people',
#   'blogging',
#   'so',
#   'many',
#   'of',
#   'the',
#   'products',
#   "don't",
#   'hit',
#   'mainstream',
#   'news.',
#   'many',
#   'of',
#   'the',
#   'products',
#   'take',
#   'too',
#   'long',
#   'to',
#   'get',
#   'developed',
#   'because',
#   'of',
#   'the',
#   'overhead',
#   'that',
#   'is',
#   'created',
#   'by',
#   'a',
#   'big',
#   'software',
#   'company,',
#   'but',
#   'oracle',
#   'does',
#   'come',
#   'with',
#   'many',
#   'useful',
#   'synergies',
#   'and',
#   'other',
#   'products',
#   'that',
#   'can',
#   'be',
#   'leveraged,',
#   'mainly',
#   'the',
#   'database.',
#   'a',
#   'few',
#   'other',
#   'downsides',
#   'are',
#   'that',
#   'much',
#   'of',
#   'the',
#   'company',
#   'is',
#   'middle',
#   'aged',
#   '(we',
#   'need',
#   'more',
#   'young',
#   'people)',
#   'and',
#   'food',
#   'is',
#   'a',
#   'tad',
#   'expensive',
#   'but',
#   'not',
#   'bad.'],
#  ['you',
#   'will',
#   'probably',
#   'make',
#   'the',
#   'minimum',
#   'salary',
#   'in',
#   'your',
#   'field',
#   'and',
#   'be',
#   'lease',
#   'appreciated.',
#   '',
#   'the',
#   'information',
#   'technology',
#   'is',
#   'at',
#   'the',
#   'bottom',
#   'of',
#   'the',
#   'company',
#   'tree',
#   'and',
#   'least',
#   'respected.',
#   '',
#   'it',
#   'is',
#   'considered',
#   'a',
#   'non-revenue',
#   'generating',
#   'group',
#   'and',
#   'the',
#   'results',
#   'are',
#   '\r\n\r\n-',
#   'no',
#   'raises\r\n-',
#   'no',
#   'bonuses',
#   '\r\n-',
#   'zero',
#   'other',
#   'incentives\r\n\r\nother',
#   'departments',
#   '(good',
#   'example',
#   'marketing',
#   'and',
#   'sales),',
#   'expense',
#   'pretty',
#   'much',
#   'everything',
#   'you',
#   'can',
#   'think',
#   'of.',
#   '',
#   'happy',
#   'ours,',
#   'lunches',
#   'and',
#   'other',
#   'unnecessary',
#   'expenses',
#   'such',
#   'as',
#   'spas',
#   'treatments'],
#  ['you',
#   'will',
#   'probably',
#   'make',
#   'the',
#   'minimum',
#   'salary',
#   'in',
#   'your',
#   'field',
#   'and',
#   'be',
#   'lease',
#   'appreciated.',
#   '',
#   'the',
#   'information',
#   'technology',
#   'is',
#   'at',
#   'the',
#   'bottom',
#   'of',
#   'the',
#   'company',
#   'tree',
#   'and',
#   'least',
#   'respected.',
#   '',
#   'it',
#   'is',
#   'considered',
#   'a',
#   'non-revenue',
#   'generating',
#   'group',
#   'and',
#   'the',
#   'results',
#   'are',
#   '\r\n\r\n-',
#   'no',
#   'raises\r\n-',
#   'no',
#   'bonuses',
#   '\r\n-',
#   'zero',
#   'other',
#   'incentives\r\n\r\nother',
#   'departments',
#   '(good',
#   'example',
#   'marketing',
#   'and',
#   'sales),',
#   'expense',
#   'pretty',
#   'much',
#   'everything',
#   'you',
#   'can',
#   'think',
#   'of.',
#   '',
#   'happy',
#   'ours,',
#   'lunches',
#   'and',
#   'other',
#   'unnecessary',
#   'expenses',
#   'such',
#   'as',
#   'spas',
#   'treatments'],
#  ['too',
#   'big',
#   'of',
#   'a',
#   'company',
#   'to',
#   'see',
#   'yourself',
#   'as',
#   'a',
#   'contributor.'],
#  ['not', 'well', 'organized,', 'options', 'not', 'worth', 'much', 'money'],
#  ['very',
#   'focused',
#   'on',
#   'the',
#   'database.',
#   'culturally',
#   'finds',
#   'it',
#   'difficult',
#   'to',
#   'accept',
#   'that',
#   'the',
#   'sales',
#   'process',
#   'is',
#   'very',
#   'different',
#   'form',
#   'database',
#   'and',
#   'addons,',
#   'to',
#   'most',
#   'of',
#   'what',
#   'they',
#   'have',
#   'acquired',
#   'in',
#   'the',
#   'middleware',
#   'or',
#   'application',
#   'tiers.'],
#  ['low',
#   'bonuses',
#   'and',
#   'other',
#   'incentives.',
#   'frugal',
#   'spending.',
#   'slow',
#   'promotions',
#   'in',
#   'some',
#   'groups.'],
#  ['lack', 'of', 'freedom', 'in', 'choosing', 'problems'],
#  ['high',
#   'pressure',
#   'situation.',
#   '',
#   'people',
#   'will',
#   'come',
#   'at',
#   'you',
#   'often.',
#   '',
#   "it's",
#   'not',
#   'a',
#   'job',
#   'where',
#   'you',
#   'just',
#   'learn',
#   'your',
#   'little',
#   'niche.',
#   '',
#   "you'll",
#   'constantly',
#   'have',
#   'to',
#   'constantly',
#   'need',
#   'to',
#   'upgrade',
#   'your',
#   'skills.'],
#  ['oracle',
#   'moves',
#   'very,',
#   'very',
#   'slowly.',
#   'if',
#   'you',
#   'want',
#   'a',
#   'fast',
#   'paced',
#   'work',
#   'environment,',
#   'look',
#   'elsewhere.',
#   'the',
#   'product',
#   'development',
#   'cycle',
#   'is',
#   'measured',
#   'in',
#   'years',
#   'instead',
#   'of',
#   'months',
#   'or',
#   'weeks.',
#   'there',
#   'seems',
#   'to',
#   'be',
#   'a',
#   'lot',
#   'of',
#   '"dead',
#   'wood"',
#   'lurking',
#   'in',
#   'the',
#   'dark',
#   'corners',
#   'of',
#   'the',
#   'company.',
#   'many',
#   'are',
#   'satisfied',
#   'to',
#   'just',
#   'stay',
#   'under',
#   'the',
#   'radar',
#   'and',
#   'collect',
#   'a',
#   'paycheck.'],
#  ['oracle',
#   'moves',
#   'very,',
#   'very',
#   'slowly.',
#   'if',
#   'you',
#   'want',
#   'a',
#   'fast',
#   'paced',
#   'work',
#   'environment,',
#   'look',
#   'elsewhere.',
#   'the',
#   'product',
#   'development',
#   'cycle',
#   'is',
#   'measured',
#   'in',
#   'years',
#   'instead',
#   'of',
#   'months',
#   'or',
#   'weeks.',
#   'there',
#   'seems',
#   'to',
#   'be',
#   'a',
#   'lot',
#   'of',
#   '"dead',
#   'wood"',
#   'lurking',
#   'in',
#   'the',
#   'dark',
#   'corners',
#   'of',
#   'the',
#   'company.',
#   'many',
#   'are',
#   'satisfied',
#   'to',
#   'just',
#   'stay',
#   'under',
#   'the',
#   'radar',
#   'and',
#   'collect',
#   'a',
#   'paycheck.'],
#  ['some', 'politics,', 'long', 'hours,', 'lots', 'of', 'new', 'products'],
#  ['reorgs',
#   'every',
#   'year',
#   'with',
#   'next',
#   'to',
#   'no',
#   'communication',
#   'regarding',
#   'structure,',
#   'reason',
#   'and',
#   'long',
#   'term',
#   'plan.',
#   '',
#   '',
#   'very',
#   'short',
#   'sighted',
#   'middle',
#   'management',
#   'with',
#   'next',
#   'to',
#   'nothing',
#   'in',
#   'communication.',
#   '',
#   'no',
#   'raises.',
#   '',
#   'oracle',
#   'will',
#   'churn',
#   'and',
#   'burn',
#   'you.',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'what',
#   'makes',
#   'you',
#   'good',
#   'is',
#   'what',
#   'makes',
#   'you',
#   'bad.',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'good',
#   'things:',
#   '',
#   '',
#   'reputation,',
#   'intellectual',
#   'capital,',
#   'products,',
#   'training,',
#   'benefits,',
#   'various',
#   'perks.',
#   '',
#   '',
#   '',
#   'bad',
#   'things:',
#   '',
#   'reputation',
#   '-',
#   'working',
#   'with',
#   'people',
#   'who',
#   'treat',
#   'each',
#   'other',
#   'like',
#   'crap',
#   'because',
#   '"we\'re',
#   'oracle"',
#   'and',
#   'this',
#   'is',
#   'how',
#   'we',
#   'do',
#   'things.',
#   'too',
#   'bad',
#   'if',
#   'mr',
#   'customer',
#   "doesn't",
#   'like',
#   'it;',
#   'intellectual',
#   'capital',
#   '-',
#   'unless',
#   'your',
#   'coming',
#   'from',
#   'stanford,',
#   'mit,',
#   'harvard',
#   'or',
#   'wharton',
#   'mba',
#   'dont',
#   'expect',
#   'to',
#   'get',
#   'all',
#   'those',
#   'special',
#   'perks.'],
#  ['reorgs',
#   'every',
#   'year',
#   'with',
#   'next',
#   'to',
#   'no',
#   'communication',
#   'regarding',
#   'structure,',
#   'reason',
#   'and',
#   'long',
#   'term',
#   'plan.',
#   '',
#   '',
#   'very',
#   'short',
#   'sighted',
#   'middle',
#   'management',
#   'with',
#   'next',
#   'to',
#   'nothing',
#   'in',
#   'communication.',
#   '',
#   'no',
#   'raises.',
#   '',
#   'oracle',
#   'will',
#   'churn',
#   'and',
#   'burn',
#   'you.',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'what',
#   'makes',
#   'you',
#   'good',
#   'is',
#   'what',
#   'makes',
#   'you',
#   'bad.',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'good',
#   'things:',
#   '',
#   '',
#   'reputation,',
#   'intellectual',
#   'capital,',
#   'products,',
#   'training,',
#   'benefits,',
#   'various',
#   'perks.',
#   '',
#   '',
#   '',
#   'bad',
#   'things:',
#   '',
#   'reputation',
#   '-',
#   'working',
#   'with',
#   'people',
#   'who',
#   'treat',
#   'each',
#   'other',
#   'like',
#   'crap',
#   'because',
#   '"we\'re',
#   'oracle"',
#   'and',
#   'this',
#   'is',
#   'how',
#   'we',
#   'do',
#   'things.',
#   'too',
#   'bad',
#   'if',
#   'mr',
#   'customer',
#   "doesn't",
#   'like',
#   'it;',
#   'intellectual',
#   'capital',
#   '-',
#   'unless',
#   'your',
#   'coming',
#   'from',
#   'stanford,',
#   'mit,',
#   'harvard',
#   'or',
#   'wharton',
#   'mba',
#   'dont',
#   'expect',
#   'to',
#   'get',
#   'all',
#   'those',
#   'special',
#   'perks.'],
#  ['the',
#   'size',
#   'of',
#   'the',
#   'team',
#   'and/or',
#   'company',
#   'is',
#   'too',
#   'big',
#   'to',
#   'maintain',
#   'overall',
#   'big',
#   'picture',
#   'of',
#   'what',
#   'the',
#   'company',
#   'is',
#   'trying',
#   'to',
#   'do.'],
#  ['oracle',
#   'is',
#   'big,',
#   'and',
#   'it',
#   'keeps',
#   'getting',
#   'bigger.',
#   'standing',
#   'out',
#   'and',
#   'getting',
#   'your',
#   'voice',
#   'heard',
#   'is',
#   'a',
#   'big',
#   'challenge.',
#   'competition',
#   'is',
#   'everywhere',
#   'and',
#   'employees',
#   'are',
#   'very',
#   'territorial,',
#   'so',
#   'focus',
#   'on',
#   'teamwork',
#   'rather',
#   'than',
#   'individual',
#   'contributions.',
#   'also,',
#   'you',
#   'may',
#   'end',
#   'up',
#   'working',
#   'here',
#   'even',
#   'if',
#   'you',
#   'go',
#   'elsewhere',
#   'due',
#   'to',
#   'constant',
#   'acquisition-based',
#   'growth.'],
#  ['there',
#   'are',
#   'only',
#   '3',
#   'companies',
#   'like',
#   'this',
#   'globally,',
#   'that',
#   'offers',
#   'one',
#   'the',
#   'oppurtunity',
#   'to',
#   'work',
#   'in',
#   'all',
#   'major',
#   'software',
#   'areas',
#   'this',
#   'is',
#   'a',
#   'drawback',
#   'when',
#   'looking',
#   'at',
#   'other',
#   'competitive',
#   'companies',
#   'to',
#   'find',
#   'employment'],
#  ['outsourcing',
#   'and',
#   'globalization.',
#   '',
#   'if',
#   'you',
#   'live',
#   'in',
#   'the',
#   'us',
#   'you',
#   'wont',
#   'be',
#   'working',
#   'for',
#   'oracle',
#   'in',
#   '10',
#   'years.',
#   '',
#   'nobody',
#   'cares',
#   'if',
#   'you',
#   'are',
#   'here',
#   'or',
#   'not,',
#   'its',
#   'very',
#   'difficult',
#   'to',
#   'work',
#   'your',
#   'way',
#   'up',
#   'the',
#   'chain.'],
#  ['the',
#   'compensation',
#   'and',
#   'leadership',
#   'abilities',
#   'of',
#   'the',
#   'management.'],
#  ['a', 'lot', 'of', 'lazy', 'and', 'incompetent', 'chinese', 'developers'],
#  ['the',
#   'compensation',
#   'and',
#   'leadership',
#   'abilities',
#   'of',
#   'the',
#   'management.'],
#  ['a', 'lot', 'of', 'lazy', 'and', 'incompetent', 'chinese', 'developers'],
#  ['promotions',
#   'tend',
#   'to',
#   'be',
#   'hard',
#   'to',
#   'get.',
#   '',
#   'typical',
#   'large',
#   'company',
#   'problems,',
#   'where',
#   'you',
#   'feel',
#   'like',
#   'you',
#   "can't",
#   'make',
#   'a',
#   'huge',
#   'difference.',
#   'sometimes',
#   'the',
#   'process',
#   'can',
#   'get',
#   'in',
#   'the',
#   'way',
#   'on',
#   'innovation.',
#   'hence',
#   'the',
#   'amount',
#   'of',
#   'small',
#   'acquisitions.',
#   'small',
#   'companies',
#   'tend',
#   'to',
#   'innovate',
#   'better',
#   'than',
#   'large',
#   'ones.'],
#  ['oracle',
#   'is',
#   'a',
#   'very',
#   'large,',
#   'complex',
#   'organization',
#   'and',
#   'can',
#   'sometimes',
#   'be',
#   'difficult',
#   'to',
#   'determine',
#   'where',
#   'to',
#   'go',
#   'or',
#   'to',
#   'whom',
#   'to',
#   'speak',
#   'for',
#   'information',
#   'and',
#   'answers.',
#   'the',
#   'company',
#   'relies',
#   'a',
#   'great',
#   'deal',
#   'on',
#   'self-service,',
#   'for',
#   'things',
#   'like',
#   'hr',
#   'and',
#   'benefits',
#   'enrollment,',
#   'expenses,',
#   'etc.,',
#   'but',
#   'sometimes',
#   'can',
#   'be',
#   'overly',
#   'reliant',
#   'on',
#   'this',
#   '-',
#   'sometimes',
#   'you',
#   'just',
#   'simply',
#   'need',
#   'to',
#   'talk',
#   'to',
#   'a',
#   'person.'],
#  ['depends',
#   'what',
#   'goups/organization',
#   'within',
#   'oracle',
#   'you',
#   'work',
#   'for.'],
#  ['huge,',
#   'so',
#   'feels',
#   'bureaucratic',
#   'at',
#   'times.',
#   'also,',
#   'kind',
#   'of',
#   'a',
#   'high',
#   'end',
#   'body',
#   'shop',
#   'really.'],
#  ['very',
#   'poor',
#   'management',
#   'and',
#   'leadership.',
#   '',
#   'promotions',
#   'handed',
#   'out',
#   'more',
#   'due',
#   'to',
#   'seniority',
#   'than',
#   'competency.',
#   '',
#   'poor',
#   'work',
#   'culture,',
#   'too',
#   'political.',
#   '',
#   'successful',
#   'careers',
#   'are',
#   'identified',
#   'with',
#   'ability',
#   'to',
#   'expand',
#   'and',
#   'build',
#   'your',
#   'empire,',
#   'which',
#   'forces',
#   'ambitious',
#   'and',
#   'motivated',
#   'people',
#   'to',
#   'emulate',
#   'those',
#   'activities',
#   'rather',
#   'than',
#   'build',
#   'competencies',
#   'to',
#   'be',
#   'truly',
#   'successful',
#   'in',
#   'a',
#   'new',
#   'position.',
#   '',
#   'no',
#   'one',
#   'ever',
#   'gets',
#   'fired',
#   'or',
#   'reprimanded',
#   'for',
#   'failure,',
#   'which',
#   'there',
#   'is',
#   'alot',
#   'of',
#   'at',
#   'oracle.',
#   '',
#   'dates',
#   'are',
#   'always',
#   'missed,',
#   'people',
#   'are',
#   'not',
#   'held',
#   'accountable.'],
#  ["it's",
#   'huge,',
#   'which',
#   'makes',
#   'it',
#   'less',
#   'efficient',
#   'than',
#   'many',
#   'smaller',
#   'companies.',
#   '',
#   'those',
#   'who',
#   'work',
#   'here',
#   'who',
#   'say',
#   'things',
#   'like',
#   '"it\'s',
#   'like',
#   'the',
#   "world's",
#   'largest',
#   'startup"',
#   "haven't",
#   'worked',
#   'for',
#   'a',
#   'startup',
#   'lately,',
#   'if',
#   'ever.',
#   '',
#   'there',
#   'are',
#   'often',
#   'far',
#   'to',
#   'many',
#   'people',
#   'involved',
#   'in',
#   'a',
#   'particular',
#   'task',
#   'or',
#   'project,',
#   'and',
#   "it's",
#   'not',
#   'always',
#   'clear',
#   'who',
#   'is',
#   'actually',
#   'in',
#   'charge.'],
#  ['having',
#   'joined',
#   'from',
#   'a',
#   'small',
#   'acquisition,',
#   'it',
#   'has',
#   'been',
#   'very',
#   'difficult',
#   'to',
#   'get',
#   'up',
#   'to',
#   'speed',
#   'on',
#   "what's",
#   'required',
#   'to',
#   'do',
#   'my',
#   'job.',
#   '',
#   'getting',
#   'information',
#   'about',
#   'other',
#   'teams/parts',
#   'of',
#   'company',
#   'to',
#   'do',
#   'my',
#   'work',
#   'is',
#   'very',
#   'difficult.',
#   '',
#   'internal',
#   'aps',
#   'and',
#   'info',
#   'sources',
#   'are',
#   'inscrutable',
#   '-',
#   'requiring',
#   'much',
#   'time',
#   'to',
#   'mine.',
#   '',
#   'even',
#   'long',
#   'time',
#   'veterans',
#   "don't",
#   'know',
#   'much',
#   'about',
#   'how',
#   'to',
#   'get',
#   'essential',
#   'info.',
#   '',
#   '',
#   'raises',
#   'were',
#   'delayed',
#   'by',
#   'months',
#   'this',
#   'past',
#   'year',
#   'and',
#   'were',
#   'not',
#   'retroactive',
#   'to',
#   'the',
#   'beginning',
#   'of',
#   'the',
#   'new',
#   'evaluation',
#   'year.',
#   '',
#   'bonuses',
#   'were',
#   'very',
#   'small',
#   'to',
#   'nothing',
#   'for',
#   'my',
#   'team,',
#   'which',
#   'is',
#   'a',
#   'pretty',
#   'strong',
#   'one.',
#   '',
#   '',
#   'as',
#   'in',
#   'many',
#   'large',
#   'companies,',
#   'some',
#   'people',
#   'seem',
#   'to',
#   'have',
#   'very',
#   'little',
#   'to',
#   'do,',
#   'while',
#   'others,',
#   'such',
#   'as',
#   'my',
#   'team,',
#   'have',
#   'deliverables',
#   'and',
#   'deadlines',
#   'that',
#   "wouldn't",
#   'be',
#   'possible',
#   'with',
#   '5',
#   "x's",
#   'the',
#   'number',
#   'of',
#   'people.',
#   '',
#   'technology',
#   'supporting',
#   'internal',
#   'processes',
#   'is',
#   'flakey',
#   'and',
#   'training',
#   'on',
#   'it',
#   'is',
#   'abysmal.'],
#  ['having',
#   'joined',
#   'from',
#   'a',
#   'small',
#   'acquisition,',
#   'it',
#   'has',
#   'been',
#   'very',
#   'difficult',
#   'to',
#   'get',
#   'up',
#   'to',
#   'speed',
#   'on',
#   "what's",
#   'required',
#   'to',
#   'do',
#   'my',
#   'job.',
#   '',
#   'getting',
#   'information',
#   'about',
#   'other',
#   'teams/parts',
#   'of',
#   'company',
#   'to',
#   'do',
#   'my',
#   'work',
#   'is',
#   'very',
#   'difficult.',
#   '',
#   'internal',
#   'aps',
#   'and',
#   'info',
#   'sources',
#   'are',
#   'inscrutable',
#   '-',
#   'requiring',
#   'much',
#   'time',
#   'to',
#   'mine.',
#   '',
#   'even',
#   'long',
#   'time',
#   'veterans',
#   "don't",
#   'know',
#   'much',
#   'about',
#   'how',
#   'to',
#   'get',
#   'essential',
#   'info.',
#   '',
#   '',
#   'raises',
#   'were',
#   'delayed',
#   'by',
#   'months',
#   'this',
#   'past',
#   'year',
#   'and',
#   'were',
#   'not',
#   'retroactive',
#   'to',
#   'the',
#   'beginning',
#   'of',
#   'the',
#   'new',
#   'evaluation',
#   'year.',
#   '',
#   'bonuses',
#   'were',
#   'very',
#   'small',
#   'to',
#   'nothing',
#   'for',
#   'my',
#   'team,',
#   'which',
#   'is',
#   'a',
#   'pretty',
#   'strong',
#   'one.',
#   '',
#   '',
#   'as',
#   'in',
#   'many',
#   'large',
#   'companies,',
#   'some',
#   'people',
#   'seem',
#   'to',
#   'have',
#   'very',
#   'little',
#   'to',
#   'do,',
#   'while',
#   'others,',
#   'such',
#   'as',
#   'my',
#   'team,',
#   'have',
#   'deliverables',
#   'and',
#   'deadlines',
#   'that',
#   "wouldn't",
#   'be',
#   'possible',
#   'with',
#   '5',
#   "x's",
#   'the',
#   'number',
#   'of',
#   'people.',
#   '',
#   'technology',
#   'supporting',
#   'internal',
#   'processes',
#   'is',
#   'flakey',
#   'and',
#   'training',
#   'on',
#   'it',
#   'is',
#   'abysmal.'],
#  ['the',
#   'company',
#   'and',
#   'database',
#   'division',
#   'have',
#   'grown',
#   'in',
#   'size',
#   'significantly',
#   'in',
#   'the',
#   'last',
#   'decade',
#   'and',
#   'have',
#   'had',
#   'creeping',
#   'bureaucracy.',
#   '',
#   'programming-in-the-large',
#   'is',
#   'never',
#   'an',
#   'easy',
#   'task.'],
#  ['you',
#   'sometimes',
#   'feel',
#   'like',
#   'a',
#   'very',
#   'small',
#   'part',
#   'of',
#   'a',
#   'giant',
#   'machine.',
#   'occasionally,',
#   'the',
#   'bureaucracy',
#   'of',
#   'daily',
#   'work',
#   '(e.g.',
#   'time',
#   'reporting)',
#   'can',
#   'get',
#   'to',
#   'be',
#   'a',
#   'drag.'],
#  ['you',
#   'sometimes',
#   'feel',
#   'like',
#   'a',
#   'very',
#   'small',
#   'part',
#   'of',
#   'a',
#   'giant',
#   'machine.',
#   'occasionally,',
#   'the',
#   'bureaucracy',
#   'of',
#   'daily',
#   'work',
#   '(e.g.',
#   'time',
#   'reporting)',
#   'can',
#   'get',
#   'to',
#   'be',
#   'a',
#   'drag.'],
#  ['because',
#   'of',
#   'the',
#   'large',
#   'size',
#   'of',
#   'oracle',
#   '(do',
#   'i',
#   'dare',
#   'say,',
#   "you're",
#   'just',
#   'a',
#   'number),',
#   'in',
#   'many',
#   'ways',
#   'you',
#   'are',
#   'more',
#   'dependent',
#   'on',
#   'having',
#   'a',
#   'good',
#   'relationship',
#   'with',
#   'your',
#   'manager.',
#   'if',
#   'your',
#   'manager',
#   'has',
#   'minimal',
#   'skills',
#   'or',
#   'simply',
#   "can't",
#   'manage,',
#   'then',
#   "you're",
#   'really',
#   'screwed.'],
#  ['a',
#   'big',
#   'company',
#   'so',
#   'sometimes',
#   'feel',
#   'lost.',
#   'hard',
#   'to',
#   'find',
#   'your',
#   'way',
#   'around.'],
#  ['large', 'company,', 'easy', 'to', 'get', 'lost', 'in', 'it.'],
#  ['too', 'many', 'people', '-', 'less', 'motivation', 'in', 'some', 'groups'],
#  ['nothing', 'important', 'that', 'needs', 'mentioning'],
#  ['nothing', 'important', 'that', 'needs', 'mentioning'],
#  ['atmosphere', 'is', 'tough', 'at', 'times'],
#  ['work',
#   'pressure',
#   'which',
#   "u'll",
#   'get',
#   'while',
#   'working',
#   'in',
#   'oracle.'],
#  ['politics', 'and', 'micromanagement.', 'poor', 'compensation', 'package.'],
#  ['politics', 'and', 'micromanagement.', 'poor', 'compensation', 'package.'],
#  ['it',
#   'is',
#   'a',
#   'very',
#   'technically',
#   'demanding',
#   'environment,',
#   'and',
#   'you',
#   'are',
#   'largely',
#   'left',
#   'on',
#   'your',
#   'own',
#   'to',
#   'sink',
#   'or',
#   'swim.'],
#  ['it',
#   'is',
#   'a',
#   'very',
#   'technically',
#   'demanding',
#   'environment,',
#   'and',
#   'you',
#   'are',
#   'largely',
#   'left',
#   'on',
#   'your',
#   'own',
#   'to',
#   'sink',
#   'or',
#   'swim.'],
#  ['very',
#   'large',
#   'organisation,',
#   'where',
#   'it',
#   'can',
#   'take',
#   'some',
#   'time',
#   'to',
#   'find',
#   'your',
#   'way',
#   'around.',
#   'its',
#   'also',
#   'feels',
#   'like',
#   'a',
#   'satellite',
#   'organisation',
#   'of',
#   'the',
#   'mother',
#   'ship',
#   'in',
#   'the',
#   'us.',
#   'career',
#   'prospects',
#   'seem',
#   'to',
#   'be',
#   'limited',
#   'considering',
#   'we',
#   'are',
#   '2',
#   'steps',
#   'away',
#   'from',
#   'hq.'],
#  ['oracle',
#   'is',
#   'big..',
#   '',
#   'and',
#   'as',
#   'such',
#   'politics',
#   'are',
#   'par',
#   'for',
#   'the',
#   'course.',
#   'however,',
#   'for',
#   'the',
#   'most',
#   'part,',
#   'its',
#   'a',
#   'bunch',
#   'of',
#   'smart',
#   'people',
#   'all',
#   'trying',
#   'to',
#   'do',
#   'well',
#   'in',
#   'their',
#   'jobs..',
#   '',
#   '',
#   'it',
#   'does',
#   'seem',
#   'like',
#   'middle',
#   'management',
#   'gets',
#   'in',
#   'the',
#   'way',
#   'of',
#   'the',
#   'workers',
#   'and',
#   'sometimes',
#   "doesn't",
#   'clearly',
#   'present',
#   'the',
#   'real',
#   'problems',
#   'to',
#   'snr',
#   'management',
#   'so',
#   'they',
#   'can',
#   'do',
#   'something',
#   'about',
#   'it.',
#   '',
#   'so',
#   'overall..',
#   'just',
#   'the',
#   'communication',
#   'flow',
#   'and',
#   'the',
#   'agility',
#   'of',
#   'the',
#   'organization',
#   'seems',
#   'to',
#   'be',
#   'slow',
#   '--',
#   'like',
#   'an',
#   'elephant.'],
#  ['oracle',
#   'is',
#   'big..',
#   '',
#   'and',
#   'as',
#   'such',
#   'politics',
#   'are',
#   'par',
#   'for',
#   'the',
#   'course.',
#   'however,',
#   'for',
#   'the',
#   'most',
#   'part,',
#   'its',
#   'a',
#   'bunch',
#   'of',
#   'smart',
#   'people',
#   'all',
#   'trying',
#   'to',
#   'do',
#   'well',
#   'in',
#   'their',
#   'jobs..',
#   '',
#   '',
#   'it',
#   'does',
#   'seem',
#   'like',
#   'middle',
#   'management',
#   'gets',
#   'in',
#   'the',
#   'way',
#   'of',
#   'the',
#   'workers',
#   'and',
#   'sometimes',
#   "doesn't",
#   'clearly',
#   'present',
#   'the',
#   'real',
#   'problems',
#   'to',
#   'snr',
#   'management',
#   'so',
#   'they',
#   'can',
#   'do',
#   'something',
#   'about',
#   'it.',
#   '',
#   'so',
#   'overall..',
#   'just',
#   'the',
#   'communication',
#   'flow',
#   'and',
#   'the',
#   'agility',
#   'of',
#   'the',
#   'organization',
#   'seems',
#   'to',
#   'be',
#   'slow',
#   '--',
#   'like',
#   'an',
#   'elephant.'],
#  ['very',
#   'competitive',
#   'and',
#   'political',
#   'environment',
#   'which',
#   'makes',
#   'it',
#   'less',
#   'team',
#   'focused',
#   'at',
#   'times',
#   '(unless',
#   'you',
#   'like',
#   'this',
#   'type',
#   'of',
#   'environment',
#   ';)'],
#  ['high', 'stress', 'lead', 'to', 'job', 'burnout'],
#  ['high', 'stress', 'lead', 'to', 'job', 'burnout'],
#  ['the',
#   'worst',
#   'part',
#   'of',
#   'working',
#   'at',
#   'oracle',
#   'as',
#   'an',
#   'engineer',
#   'or',
#   'engineering',
#   'manager',
#   'is',
#   'that',
#   'innovation',
#   'is',
#   'regularly',
#   'frowned',
#   'upon',
#   'unless',
#   'you',
#   'are',
#   'one',
#   'of',
#   'the',
#   '"blessed"',
#   'employees',
#   'who',
#   'have',
#   'the',
#   'attention',
#   'of',
#   'executives.',
#   'others',
#   'innovative',
#   '(or',
#   'disruptive)',
#   'ideas',
#   'get',
#   'quashed',
#   'and',
#   'the',
#   'perpetrator',
#   'is',
#   'labeled',
#   'as',
#   'an',
#   'irritant.',
#   'this',
#   'job',
#   'is',
#   'usually',
#   'accomplished',
#   'by',
#   'the',
#   'crushing',
#   'bureaucracy',
#   'which',
#   'tries',
#   'to',
#   'integrate',
#   'too',
#   'many',
#   'disparate',
#   'technologies',
#   'for',
#   'the',
#   'sake',
#   'of',
#   're-use,',
#   'but',
#   'at',
#   'the',
#   'same',
#   'time',
#   'has',
#   'not',
#   'mastered',
#   'integration',
#   'and',
#   'causes',
#   'maddening',
#   'delays',
#   'to',
#   'product',
#   'cycles.\r\nemployees',
#   "aren't",
#   'valued',
#   'highly.',
#   'the',
#   'benefits',
#   'at',
#   'oracle',
#   'are',
#   'mediocre',
#   'compared',
#   'to',
#   'many',
#   'other',
#   'giganto-tech',
#   'companies,',
#   'and',
#   'the',
#   'company',
#   'is',
#   'always',
#   'looking',
#   'for',
#   'ways',
#   'to',
#   'cut',
#   'corners.\r\nmany',
#   'senior',
#   'managers',
#   'will',
#   'stomp',
#   'on',
#   'their',
#   'employees',
#   'to',
#   'work',
#   'their',
#   'way',
#   'to',
#   'the',
#   'top.'],
#  ['being',
#   'part',
#   'of',
#   'development',
#   'is',
#   'painful,',
#   "it's",
#   'like',
#   'being',
#   'in',
#   'quicksand.',
#   'it',
#   'moves',
#   'so',
#   'slow,',
#   'most',
#   'of',
#   'your',
#   'time',
#   'is',
#   'watching',
#   'your',
#   'back',
#   'from',
#   'all',
#   'the',
#   'politics.',
#   'oracle',
#   'really',
#   'no',
#   'longer',
#   'cares',
#   'about',
#   'developers.',
#   "it's",
#   'a',
#   'nasty',
#   'and',
#   'grim',
#   'place',
#   'to',
#   'work.'],
#  ['being',
#   'part',
#   'of',
#   'development',
#   'is',
#   'painful,',
#   "it's",
#   'like',
#   'being',
#   'in',
#   'quicksand.',
#   'it',
#   'moves',
#   'so',
#   'slow,',
#   'most',
#   'of',
#   'your',
#   'time',
#   'is',
#   'watching',
#   'your',
#   'back',
#   'from',
#   'all',
#   'the',
#   'politics.',
#   'oracle',
#   'really',
#   'no',
#   'longer',
#   'cares',
#   'about',
#   'developers.',
#   "it's",
#   'a',
#   'nasty',
#   'and',
#   'grim',
#   'place',
#   'to',
#   'work.'],
#  ['no', 'big', 'upside', 'in', 'compensation'],
#  ["it's",
#   'a',
#   'big',
#   'company,',
#   'so',
#   'sometimes',
#   'things',
#   'are',
#   'slow,',
#   'but',
#   'be',
#   'patient,',
#   'everything',
#   'will',
#   'go',
#   'through',
#   'finally.'],
#  ['internal',
#   'information',
#   'access',
#   'is',
#   'awful.\r\n\r\npeople',
#   'are',
#   'afraid',
#   'for',
#   'their',
#   'jobs\r\n\r\nsome',
#   'of',
#   'the',
#   'internal',
#   'tools',
#   'are',
#   'dated.\r\n\r\nsales',
#   'folks',
#   'tend',
#   'to',
#   'be',
#   'a',
#   'little',
#   'arrogant.'],
#  ['everything', 'is', 'fine.', 'i', 'dont', 'see', 'any', 'disadvetages.'],
#  ['incompetent',
#   'management,',
#   'favoritism,',
#   'antiquated',
#   'management',
#   'practices'],
#  ['hardwork',
#   'or',
#   'smart',
#   'people',
#   'stay',
#   'at',
#   'the',
#   'bottom',
#   'of',
#   'the',
#   'hierarchy.',
#   'one',
#   'has',
#   'to',
#   'play',
#   'politics',
#   'to',
#   'grow',
#   'up',
#   'the',
#   'ladder.'],
#  ['too',
#   'much',
#   'politics',
#   'and',
#   'no',
#   'direct',
#   'guidence',
#   'of',
#   'product',
#   'direction.',
#   '',
#   'too',
#   'complex',
#   'of',
#   'development',
#   'environment',
#   'to',
#   'be',
#   'productive.',
#   '',
#   'just',
#   'like',
#   'any',
#   'big',
#   'companies,',
#   'you',
#   'are',
#   'not',
#   'recognized',
#   'by',
#   'the',
#   'good',
#   'work',
#   'you',
#   'did.',
#   '',
#   'the',
#   'bonus',
#   'and',
#   'salary',
#   'raise',
#   'often',
#   'tie',
#   'to',
#   'your',
#   "manager's",
#   'relationship',
#   'with',
#   'senior',
#   'management.'],
#  ['career',
#   'development',
#   'is',
#   'largely',
#   'in',
#   'the',
#   'hands',
#   'of',
#   'each',
#   'employee,',
#   'and',
#   'opportunities',
#   'vary',
#   'depending',
#   'on',
#   'the',
#   'savvy',
#   'of',
#   'each',
#   "area's",
#   'management.',
#   'the',
#   'long',
#   'adoption',
#   'cycle',
#   'for',
#   'products',
#   'means',
#   'that',
#   'it',
#   'can',
#   'take',
#   'a',
#   'long',
#   'time',
#   'before',
#   'your',
#   'cool',
#   'new',
#   'feature',
#   'has',
#   'a',
#   'big',
#   'impact.',
#   'old-timers',
#   'and',
#   'teams',
#   'from',
#   'newly',
#   'acquired',
#   'companies',
#   'find',
#   'themselves',
#   'competing',
#   'to',
#   'prove',
#   "who's",
#   'product',
#   'and',
#   'processes',
#   'deserve',
#   'to',
#   'become',
#   'the',
#   'standard.',
#   'some',
#   'people',
#   'operate,',
#   'and',
#   'some',
#   'managers',
#   'manage,',
#   'out',
#   'of',
#   'an',
#   'inordinate',
#   'fear',
#   'of',
#   'getting',
#   'fired.'],
#  ['each',
#   'group',
#   'has',
#   'its',
#   'own',
#   'management/promotion',
#   'policies.',
#   'the',
#   'group',
#   'i',
#   'was',
#   'in',
#   'did',
#   'not',
#   'promote',
#   'my',
#   'career',
#   'growth.',
#   'for',
#   'several',
#   'years',
#   'there',
#   'was',
#   'no',
#   'raises',
#   'or',
#   'bonuses.',
#   'be',
#   'it',
#   'in',
#   'technical',
#   'track',
#   'or',
#   'management',
#   'track',
#   'the',
#   'career',
#   'path',
#   'is',
#   'not',
#   'well',
#   'defined.',
#   'again',
#   'this',
#   'was',
#   'in',
#   'one',
#   'group,',
#   'but',
#   'i',
#   'have',
#   'heard',
#   'of',
#   'employees',
#   'being',
#   'very',
#   'happy',
#   'in',
#   'other',
#   'groups.',
#   'i',
#   'would',
#   'strongly',
#   'recommend',
#   'talking',
#   'to',
#   'more',
#   'people',
#   'in',
#   'the',
#   'group',
#   'you',
#   'are',
#   'joining',
#   'before',
#   'you',
#   'accept',
#   'the',
#   'position.',
#   'during',
#   'the',
#   'interview',
#   'process,',
#   'do',
#   'request',
#   'for',
#   'time',
#   'with',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'team',
#   'and',
#   'talk',
#   'to',
#   'your',
#   'peers',
#   'to',
#   'get',
#   'a',
#   'good',
#   'handle',
#   'on',
#   'what',
#   'the',
#   'job',
#   'is',
#   'about.'],
#  ['the', 'management', 'is', 'less', 'then', 'desirable.'],
#  ['compensation', 'is', 'not', 'very', 'competitive'],
#  ['compensation', 'is', 'not', 'up', 'to', 'the', 'mark'],
#  ['too',
#   'big',
#   'of',
#   'a',
#   'company',
#   'to',
#   'make',
#   'an',
#   'impact,',
#   'very',
#   'political'],
#  ['pay', 'is', 'not', 'so', 'good'],
#  ['very',
#   'structured',
#   'and',
#   'unflexible',
#   'in',
#   'your',
#   'role.',
#   'have',
#   'adhere',
#   'to',
#   'upper',
#   'management'],
#  ['1.',
#   'cares',
#   'about',
#   'product',
#   'delivery',
#   'on',
#   'time',
#   'but',
#   'not',
#   'their',
#   'appraisals/hikes/bonuses\r\n2.',
#   'not',
#   'a',
#   'employee',
#   'friendly',
#   'company\r\n3.',
#   'bonuses',
#   'and',
#   'hikes',
#   'are',
#   'pathetic.',
#   '\r\n4.',
#   'performance',
#   'reviews',
#   'not',
#   'done',
#   'on',
#   'time',
#   'as',
#   'well',
#   'as',
#   'no',
#   'proper',
#   'goal',
#   'settings',
#   'in',
#   'most',
#   'groups.\r\n5.',
#   'no',
#   'direction',
#   'about',
#   'future',
#   'releases',
#   'to',
#   'employees',
#   '(kept',
#   'secretive)\r\n6.',
#   'no',
#   'spot',
#   'recognitions.\r\n7.',
#   'expected',
#   'to',
#   'work',
#   '24x7',
#   'because',
#   'of',
#   'scattered',
#   'team',
#   'members\r\n8.',
#   'too',
#   'big',
#   'and',
#   'your',
#   'hardwork',
#   'may',
#   'not',
#   'be',
#   'appreciated',
#   'by',
#   'anything',
#   'monetary.'],
#  ['not', 'enough', 'completive', 'salary', 'for', 'technical', 'people'],
#  ['compensation',
#   'is',
#   'terrible.',
#   '',
#   'why',
#   'do',
#   'you',
#   'have',
#   'salary',
#   'bands',
#   'if',
#   'you',
#   'are',
#   'never',
#   'in',
#   'them?'],
#  ['ordinary', 'compensation,', 'very', 'typical', 'of', 'a', 'big', 'company'],
#  ['with',
#   'large',
#   'companies',
#   'you',
#   'can',
#   'get',
#   'lost',
#   'in',
#   'the',
#   'masses.',
#   'the',
#   'communications',
#   'up',
#   'the',
#   'management',
#   'chain',
#   'can',
#   'be',
#   'laborious',
#   '(you',
#   'really',
#   'have',
#   'to',
#   'push',
#   'to',
#   'move',
#   'things',
#   'up',
#   'the',
#   'ladder).'],
#  ['travel',
#   'requirements',
#   'along',
#   'with',
#   'being',
#   'stretched',
#   'over',
#   'numerous',
#   'projects',
#   'at',
#   'the',
#   'same',
#   'time',
#   'leave',
#   'no',
#   'room',
#   'for',
#   'a',
#   'personal',
#   'life.',
#   '',
#   'the',
#   'company',
#   'policy',
#   'not',
#   'to',
#   'hire',
#   'additional',
#   'resources',
#   'to',
#   'help',
#   'greatly',
#   'hinders',
#   'any',
#   'family',
#   'time.'],
#  ['its',
#   'big!',
#   'so',
#   'a',
#   'lot',
#   'of',
#   'people',
#   'seem',
#   'lost.\r\nmy',
#   'knowledge',
#   'is',
#   'limited',
#   'to',
#   'fusion',
#   'middleware',
#   '(application',
#   'server)',
#   'platform',
#   'area',
#   'and',
#   'cannot',
#   'comment',
#   'of',
#   'db',
#   'or',
#   'apps',
#   'teams',
#   '-',
#   'the',
#   'problems',
#   'are',
#   '\r\n-',
#   'dysfunctional',
#   '-',
#   'there',
#   'is',
#   'the',
#   '',
#   'obvious',
#   '"right',
#   'arm',
#   "doesn't",
#   'know',
#   'what',
#   'left',
#   'arm',
#   'is',
#   'doing"',
#   'syndrome.\r\n-',
#   'sdlc',
#   'is',
#   'not',
#   'strictly',
#   'followed',
#   '--',
#   'engineering',
#   'process',
#   'gets',
#   'a',
#   'little',
#   'chaotic/',
#   'ad',
#   'hoc.',
#   'the',
#   'initial',
#   'set',
#   'of',
#   'requirements/restrictions',
#   'that',
#   'you',
#   'start',
#   'with',
#   'almost',
#   'never',
#   'hold',
#   'true.',
#   'some',
#   'thing',
#   'or',
#   'the',
#   'other',
#   'will',
#   'change',
#   'and',
#   "you'll",
#   'have',
#   'to',
#   'accommodate',
#   'for',
#   'it.',
#   '\r\n-',
#   'schedules',
#   'are',
#   'very',
#   'aggressive',
#   'but',
#   'in',
#   'my',
#   'opinion',
#   'not',
#   'realistic.',
#   'to',
#   'give',
#   'an',
#   'example,',
#   'product',
#   "hasn't",
#   'shipped',
#   '18',
#   'months',
#   'after',
#   'a',
#   'previously',
#   'advertised',
#   '"code',
#   'freeze"',
#   'date.\r\n-',
#   'you',
#   'work',
#   'a',
#   'lot',
#   'but',
#   'get',
#   'a',
#   'sense',
#   'of',
#   'not',
#   'having',
#   'achieved',
#   'as',
#   'much.',
#   '\r\n-',
#   'if',
#   'you',
#   'like',
#   'to',
#   'code',
#   'a',
#   'lot,',
#   'then',
#   'this',
#   "isn't",
#   'the',
#   'place',
#   ':(\r\n-',
#   'nobody',
#   'makes',
#   'firm',
#   'commitments',
#   'on',
#   'requirements/schedules',
#   '-',
#   'i',
#   'guess',
#   'it',
#   'is',
#   'a',
#   'way',
#   'to',
#   'make',
#   'sure',
#   'anything',
#   'you',
#   "don't",
#   'know',
#   'now',
#   'can',
#   'be',
#   'made',
#   'a',
#   '"requirement"',
#   'later.'],
#  ['long', 'hours,', 'travel,', 'very', 'competitive'],
#  ['in',
#   'many',
#   'ways',
#   'oracle',
#   "doesn't",
#   'know',
#   'how',
#   'to',
#   'deal',
#   'with',
#   'consultants.',
#   'they',
#   'were',
#   'and',
#   'are',
#   'a',
#   'great',
#   'database',
#   'company',
#   'and',
#   'probably',
#   'should',
#   'have',
#   'stayed',
#   'in',
#   'that',
#   'business.',
#   'once',
#   'peoplesoft',
#   'was',
#   'purchased',
#   'they',
#   'should',
#   'have',
#   'dropped',
#   'the',
#   'line',
#   'of',
#   'oracle',
#   'hr',
#   'software',
#   'and',
#   'embraced',
#   'peoplesoft',
#   'software.'],
#  ['you',
#   'get',
#   'used',
#   'to',
#   'oracle',
#   'culture',
#   'and',
#   'you',
#   'become',
#   'a',
#   'lazy',
#   'bum.',
#   '',
#   'you',
#   'learn',
#   'that',
#   'its',
#   'more',
#   'important',
#   'to',
#   'act',
#   'busy',
#   'rather',
#   'than',
#   'actually',
#   'being',
#   'busy.'],
#  ['none', 'that', 'i', 'can', 'think', 'of'],
#  ['miserable',
#   'salaries,',
#   'continuous',
#   'pressure',
#   'for',
#   'performance,',
#   'but',
#   'no',
#   'appreciation',
#   'of',
#   'good',
#   'work',
#   'done.',
#   'very',
#   'little',
#   'chances',
#   'of',
#   'growth.',
#   'the',
#   'appraisal',
#   'is',
#   'a',
#   'slow',
#   'and',
#   'painful',
#   'process.',
#   'i',
#   'am',
#   'not',
#   'sure',
#   'if',
#   'the',
#   'feedback',
#   'given',
#   'is',
#   'looked',
#   'at',
#   'by',
#   'the',
#   'senior',
#   'management.'],
#  ['majority',
#   'of',
#   'development',
#   'managers',
#   'and',
#   'directors',
#   'do',
#   'not',
#   'know',
#   'what',
#   'they',
#   'are',
#   'doing.',
#   'this',
#   'is',
#   'very',
#   'bad',
#   'for',
#   'the',
#   'future',
#   'growth',
#   'of',
#   'the',
#   'company',
#   'as',
#   'they',
#   'drive',
#   'good,',
#   'talented',
#   'people',
#   'by',
#   'their',
#   'lack',
#   'of',
#   'knowledge.'],
#  ['downward', 'salary', 'pressure', 'due', 'to', 'off', 'shoring'],
#  ['one',
#   'of',
#   'the',
#   'downsides',
#   'to',
#   'working',
#   'for',
#   'oracle',
#   'fs',
#   'is',
#   'the',
#   'internal',
#   'policies',
#   'and',
#   'precedures',
#   '(althought',
#   'nessicary)',
#   'sometimes',
#   'being',
#   'a',
#   'pain',
#   'to',
#   'deal',
#   'with.'],
#  ['salary',
#   'adjustments',
#   'and',
# ...
#   'and',
#   'hard',
#   'to',
#   'understand\r\ntoo',
#   'much',
#   'bureaucracy\r\nlittle',
#   'impact',
#   'unless',
#   'you',
#   'are',
#   'senior'],
#  ['little',
#   'management',
#   'respect',
#   'for',
#   'the',
#   'customer',
#   'support',
#   'organization,',
#   'little',
#   'or',
#   'no',
#   'training',
#   'or',
#   'time',
#   'for',
#   'self-learning',
#   'in',
#   'customer',
#   'support.',
#   '',
#   'upper',
#   'management',
#   'culture',
#   'is',
#   'one',
#   'of',
#   'bullies,',
#   'profanity,',
#   'and',
#   'ego.',
#   '',
#   'took',
#   'away',
#   'all',
#   'of',
#   'the',
#   'bonus',
#   'plan',
#   'for',
#   'non-management.',
#   '',
#   'no',
#   'incentive',
#   'to',
#   'go',
#   'the',
#   'extra',
#   'mile',
#   'for',
#   'customers',
#   '-',
#   'very',
#   'few',
#   'rewards',
#   'or',
#   'acknowledgment',
#   'for',
#   'superior',
#   'performance.'],
#  ['company',
#   'is',
#   'sales',
#   'drive',
#   'and',
#   'engineers',
#   'do',
#   'not',
#   'have',
#   'a',
#   'lot',
#   'of',
#   'opportunities',
#   'to',
#   'grow.'],
#  ['managers', 'are', 'old', 'school', '..very', 'few', 'creative', 'thinkers'],
#  ['-',
#   'sometimes',
#   'very',
#   'bureaucratic\r\n-',
#   'lots',
#   'of',
#   'internal',
#   'admin',
#   'work',
#   'to',
#   'be',
#   'done\r\n-',
#   'lots',
#   'of',
#   'politics',
#   'involved\r\n-',
#   'high',
#   'turn',
#   'over',
#   'in',
#   'sales'],
#  ['since',
#   'being',
#   'huge',
#   'in',
#   'operations,',
#   'less',
#   'personality',
#   'development'],
#  ['salary',
#   'hike',
#   'and',
#   'bonus',
#   'are',
#   'lagging',
#   'in',
#   'the',
#   'industry.',
#   '',
#   'and',
#   'out-performer',
#   'may',
#   'not',
#   'be',
#   'rewarded',
#   'properly.'],
#  ['cons:\r\n\r\nfirst',
#   'of',
#   'all',
#   'the',
#   'balance',
#   'personal',
#   'life/work',
#   'is',
#   '0',
#   '(because',
#   '0',
#   'divided',
#   'by',
#   'anything',
#   'is',
#   '0',
#   ':).',
#   'theoretically',
#   'i',
#   'was',
#   'paid',
#   'for',
#   '39',
#   'hours',
#   'but',
#   'adding',
#   'the',
#   'extra',
#   'hours',
#   'and',
#   'travelling',
#   'i',
#   'went',
#   'on',
#   'normal',
#   'bases',
#   'to',
#   '60-70',
#   'hours',
#   'of',
#   'work',
#   'per',
#   'week.',
#   'however',
#   'the',
#   'weekends',
#   'and',
#   '4',
#   'weeks',
#   'of',
#   'vacation',
#   'were',
#   'mine',
#   '(i',
#   'never',
#   'worked',
#   '1',
#   'weekend',
#   'in',
#   '4',
#   'years).',
#   'this',
#   'can',
#   'be',
#   'ok',
#   'if',
#   'you',
#   "don't",
#   'have',
#   'a',
#   'family,',
#   'but',
#   'if',
#   'you',
#   'have',
#   'one',
#   'and',
#   'you',
#   "don't",
#   'want',
#   'to',
#   'divorce,',
#   'sooner',
#   'or',
#   'later',
#   'you',
#   'will',
#   'end',
#   'up',
#   'by',
#   'searching',
#   'something',
#   'else.',
#   'i',
#   'can',
#   'mention',
#   'that',
#   'the',
#   '75%',
#   'of',
#   'my',
#   'colleagues',
#   'are',
#   'singles',
#   '(without',
#   'a',
#   'serious',
#   'very',
#   'long-term',
#   'relationship).\r\n\r\nnever',
#   'expect',
#   'a',
#   'promotion',
#   'or',
#   'a',
#   'salary',
#   'growth.',
#   'if',
#   'however',
#   'you',
#   'succeed',
#   'to',
#   'be',
#   'promoted',
#   'after',
#   'years',
#   'your',
#   'manager',
#   'will',
#   'explain',
#   'you',
#   'how',
#   'appreciated',
#   'you',
#   'are',
#   'in',
#   'the',
#   'company,',
#   'but',
#   'that',
#   'the',
#   'situation',
#   'is',
#   'bad',
#   '(either',
#   'if',
#   'the',
#   'shares',
#   'are',
#   'going',
#   'up',
#   'on',
#   'market)',
#   'and',
#   'that',
#   'the',
#   'promotion',
#   'will',
#   'not',
#   'be',
#   'noticeable',
#   'in',
#   'salary.',
#   'but',
#   'this',
#   'is',
#   'what',
#   "it's",
#   'happening',
#   'in',
#   'other',
#   'big',
#   'companies',
#   'as',
#   'well,',
#   'so',
#   'the',
#   'new',
#   'strategy',
#   'i',
#   'see',
#   'is:',
#   'stay',
#   '3-5',
#   'years',
#   'with',
#   'a',
#   'company,',
#   'then',
#   'get',
#   'a',
#   '"promotion"',
#   'in',
#   'other',
#   'company',
#   'for',
#   '3-4',
#   'years',
#   'and',
#   'then',
#   'come',
#   'back',
#   'again',
#   'to',
#   'oracle',
#   'to',
#   'be',
#   '"promoted"',
#   'to',
#   'a',
#   'job',
#   'that',
#   'you',
#   'would',
#   'not',
#   'reach',
#   'inside',
#   'in',
#   '20',
#   'years.\r\n\r\nnever',
#   'expect',
#   'a',
#   'financial',
#   'recognition',
#   'for',
#   'your',
#   'exceptional',
#   'work.\r\n\r\nbetter',
#   'get',
#   'used',
#   'that',
#   'you',
#   "don't",
#   'get',
#   'the',
#   'end',
#   'of',
#   'year',
#   'bonus',
#   '(if',
#   'this',
#   'is',
#   'related',
#   'somehow',
#   'with',
#   'the',
#   'performances',
#   'of',
#   'the',
#   'company',
#   'and',
#   'not',
#   'a',
#   'commission',
#   'of',
#   'your',
#   'work...',
#   'so',
#   'i',
#   "don't",
#   'speak',
#   'here',
#   'about',
#   'a',
#   'sales',
#   'bonus',
#   'for',
#   'example).',
#   'if',
#   'you',
#   'get',
#   'it',
#   'you',
#   'have',
#   'why',
#   'to',
#   'be',
#   'happy,',
#   'but',
#   '3',
#   'out',
#   'of',
#   '4',
#   'years',
#   'you',
#   'will',
#   'not',
#   'get',
#   'it.\r\n\r\nnever',
#   'expect',
#   'to',
#   'apply',
#   'internally',
#   'to',
#   'find',
#   'another',
#   'job',
#   'in',
#   'oracle',
#   '(especially',
#   'cross-countries).'],
#  ['-',
#   'if',
#   'you',
#   "don't",
#   'ask,',
#   'you',
#   'would',
#   'not',
#   'get..',
#   'true',
#   'for',
#   'promotions',
#   'and',
#   'hikes\r\n-',
#   'not',
#   'much',
#   'emphasis',
#   'on',
#   'merit\r\n-',
#   'middle',
#   'level',
#   'management',
#   'not',
#   'technically',
#   'competent\r\n-',
#   'too',
#   'much',
#   'processes\r\n-',
#   'hr',
#   'and',
#   'operational',
#   'department',
#   'sucks(w.r.t',
#   'india',
#   'location)'],
#  ['it',
#   'has',
#   'very',
#   'low',
#   'salary',
#   'in',
#   'oracle',
#   'asia',
#   'research',
#   'and',
#   'development',
#   'center\r\ntoo',
#   'many',
#   'managers',
#   'who',
#   'lack',
#   'of',
#   'leadership',
#   'and',
#   'necessary',
#   'technical',
#   'background'],
#  ['no',
#   'growth',
#   'prospects',
#   ',',
#   'you',
#   'need',
#   'to',
#   'have',
#   'contacts',
#   'than',
#   'talent'],
#  ['no',
#   'growth',
#   'prospects',
#   ',',
#   'you',
#   'need',
#   'to',
#   'have',
#   'contacts',
#   'than',
#   'talent'],
#  ['the',
#   'last',
#   'thing',
#   'i',
#   'remember',
#   'at',
#   'oracle',
#   'is',
#   'coming',
#   'in',
#   'one',
#   'day',
#   'to',
#   'see',
#   'my',
#   'boss',
#   'interviewing',
#   'my',
#   'replacement.',
#   '',
#   'it',
#   'was',
#   'terrible.'],
#  ['the',
#   'last',
#   'thing',
#   'i',
#   'remember',
#   'at',
#   'oracle',
#   'is',
#   'coming',
#   'in',
#   'one',
#   'day',
#   'to',
#   'see',
#   'my',
#   'boss',
#   'interviewing',
#   'my',
#   'replacement.',
#   '',
#   'it',
#   'was',
#   'terrible.'],
#  ['every',
#   'increment/discount',
#   'change',
#   'requires',
#   'top',
#   'management',
#   "'s",
#   'approval'],
#  ['every',
#   'increment/discount',
#   'change',
#   'requires',
#   'top',
#   'management',
#   "'s",
#   'approval'],
#  ['bureaucracy',
#   'at',
#   'its',
#   'highest.',
#   'too',
#   'inconspicuous.',
#   'not',
#   'employee',
#   'centric.',
#   'does',
#   'not',
#   'really',
#   'care',
#   'for',
#   'employee',
#   'like',
#   'sun/google/salesforce.',
#   'very',
#   'very',
#   'money',
#   'minded',
#   '(which',
#   'is',
#   'kinda',
#   'good).'],
#  ['there',
#   'is',
#   'very',
#   'little',
#   'planned',
#   'leadership',
#   'or',
#   'accountability.',
#   '',
#   'crisis',
#   'management',
#   'seems',
#   'to',
#   'rule',
#   'the',
#   'day.',
#   '',
#   'if',
#   'someones',
#   'continually',
#   'screws',
#   'up',
#   'as',
#   'an',
#   'employee',
#   'or',
#   'a',
#   'manager,',
#   'no',
#   'one',
#   'takes',
#   'the',
#   'time',
#   'to',
#   'address',
#   'the',
#   'issue',
#   'or',
#   'fix',
#   'the',
#   'problem.\r\n\r\na',
#   'very',
#   'ethically-challenged',
#   'organization.',
#   '',
#   'you',
#   'are',
#   'required',
#   'to',
#   'take',
#   'ethics',
#   'training',
#   'every',
#   '2',
#   'years,',
#   'and',
#   'you',
#   'just',
#   'look',
#   'around',
#   'and',
#   'see',
#   'all',
#   'of',
#   'the',
#   'violations.',
#   '',
#   'some',
#   'are',
#   'downright',
#   'criminal.',
#   '',
#   'but',
#   'what',
#   'do',
#   'you',
#   'do',
#   'when',
#   'larry',
#   'himself',
#   'has',
#   'a',
#   'enormous',
#   'conflict',
#   'of',
#   'interest',
#   '(see',
#   'netsuite)?',
#   '',
#   'i',
#   'also',
#   "don't",
#   'trust',
#   'the',
#   'anonymity',
#   'of',
#   'the',
#   'tool',
#   'used',
#   'to',
#   'report',
#   'violations.\r\n\r\nthe',
#   'company',
#   'loves',
#   'to',
#   'offshore',
#   'and',
#   'use',
#   'h1-b',
#   'workers.',
#   '',
#   'the',
#   'problem',
#   'here',
#   'is',
#   'they',
#   'seem',
#   'to',
#   'hire',
#   'very',
#   'incompetent',
#   'people.',
#   '',
#   '',
#   'your',
#   'job',
#   'will',
#   'be',
#   'to',
#   'put',
#   'out',
#   'fires',
#   'that',
#   'they',
#   'create.\r\n\r\nmiddle',
#   'management',
#   'knows',
#   'whats',
#   'going',
#   'on,',
#   'but',
#   'has',
#   'no',
#   'authority',
#   'to',
#   'do',
#   'anything.',
#   '',
#   'whether',
#   'it',
#   'is',
#   'rewarding',
#   'job',
#   'performance,',
#   'hiring',
#   'or',
#   'firing',
#   'people,',
#   'everything',
#   'is',
#   'run',
#   'from',
#   'the',
#   'top.',
#   '',
#   'this',
#   'means',
#   'you',
#   'get',
#   'the',
#   'same',
#   'bonus',
#   'at',
#   'the',
#   'guy',
#   'who',
#   'shows',
#   'up',
#   'to',
#   'work',
#   '3',
#   'days',
#   'a',
#   'week.',
#   '',
#   'this',
#   'also',
#   'makes',
#   'it',
#   'very',
#   'undesirable',
#   'to',
#   'pursue',
#   'a',
#   'career',
#   'here.'],
#  ['bureaucracy',
#   'at',
#   'its',
#   'highest.',
#   'too',
#   'inconspicuous.',
#   'not',
#   'employee',
#   'centric.',
#   'does',
#   'not',
#   'really',
#   'care',
#   'for',
#   'employee',
#   'like',
#   'sun/google/salesforce.',
#   'very',
#   'very',
#   'money',
#   'minded',
#   '(which',
#   'is',
#   'kinda',
#   'good).'],
#  ['there',
#   'is',
#   'very',
#   'little',
#   'planned',
#   'leadership',
#   'or',
#   'accountability.',
#   '',
#   'crisis',
#   'management',
#   'seems',
#   'to',
#   'rule',
#   'the',
#   'day.',
#   '',
#   'if',
#   'someones',
#   'continually',
#   'screws',
#   'up',
#   'as',
#   'an',
#   'employee',
#   'or',
#   'a',
#   'manager,',
#   'no',
#   'one',
#   'takes',
#   'the',
#   'time',
#   'to',
#   'address',
#   'the',
#   'issue',
#   'or',
#   'fix',
#   'the',
#   'problem.\r\n\r\na',
#   'very',
#   'ethically-challenged',
#   'organization.',
#   '',
#   'you',
#   'are',
#   'required',
#   'to',
#   'take',
#   'ethics',
#   'training',
#   'every',
#   '2',
#   'years,',
#   'and',
#   'you',
#   'just',
#   'look',
#   'around',
#   'and',
#   'see',
#   'all',
#   'of',
#   'the',
#   'violations.',
#   '',
#   'some',
#   'are',
#   'downright',
#   'criminal.',
#   '',
#   'but',
#   'what',
#   'do',
#   'you',
#   'do',
#   'when',
#   'larry',
#   'himself',
#   'has',
#   'a',
#   'enormous',
#   'conflict',
#   'of',
#   'interest',
#   '(see',
#   'netsuite)?',
#   '',
#   'i',
#   'also',
#   "don't",
#   'trust',
#   'the',
#   'anonymity',
#   'of',
#   'the',
#   'tool',
#   'used',
#   'to',
#   'report',
#   'violations.\r\n\r\nthe',
#   'company',
#   'loves',
#   'to',
#   'offshore',
#   'and',
#   'use',
#   'h1-b',
#   'workers.',
#   '',
#   'the',
#   'problem',
#   'here',
#   'is',
#   'they',
#   'seem',
#   'to',
#   'hire',
#   'very',
#   'incompetent',
#   'people.',
#   '',
#   '',
#   'your',
#   'job',
#   'will',
#   'be',
#   'to',
#   'put',
#   'out',
#   'fires',
#   'that',
#   'they',
#   'create.\r\n\r\nmiddle',
#   'management',
#   'knows',
#   'whats',
#   'going',
#   'on,',
#   'but',
#   'has',
#   'no',
#   'authority',
#   'to',
#   'do',
#   'anything.',
#   '',
#   'whether',
#   'it',
#   'is',
#   'rewarding',
#   'job',
#   'performance,',
#   'hiring',
#   'or',
#   'firing',
#   'people,',
#   'everything',
#   'is',
#   'run',
#   'from',
#   'the',
#   'top.',
#   '',
#   'this',
#   'means',
#   'you',
#   'get',
#   'the',
#   'same',
#   'bonus',
#   'at',
#   'the',
#   'guy',
#   'who',
#   'shows',
#   'up',
#   'to',
#   'work',
#   '3',
#   'days',
#   'a',
#   'week.',
#   '',
#   'this',
#   'also',
#   'makes',
#   'it',
#   'very',
#   'undesirable',
#   'to',
#   'pursue',
#   'a',
#   'career',
#   'here.'],
#  ['1.',
#   'deadline',
#   'pressures',
#   'can',
#   'be',
#   'taxing.\r\n2.',
#   'release',
#   'deadlines',
#   'keep',
#   'changing',
#   'at',
#   'times.\r\n3.',
#   'disbalance',
#   'between',
#   'work',
#   'and',
#   'life.\r\nrest',
#   'good',
#   'place'],
#  ['1.',
#   'deadline',
#   'pressures',
#   'can',
#   'be',
#   'taxing.\r\n2.',
#   'release',
#   'deadlines',
#   'keep',
#   'changing',
#   'at',
#   'times.\r\n3.',
#   'disbalance',
#   'between',
#   'work',
#   'and',
#   'life.\r\nrest',
#   'good',
#   'place'],
#  ['if',
#   'you',
#   'are',
#   'expecting',
#   'a',
#   '"touchy',
#   'feely"',
#   'environment',
#   'where',
#   'your',
#   'individual',
#   'skills',
#   'are',
#   'respected',
#   'and',
#   'your',
#   'value',
#   'to',
#   'the',
#   'company',
#   'is',
#   'well',
#   'recognized,',
#   'you',
#   'will',
#   'be',
#   'disappointed.',
#   'senior',
#   'management',
#   'especially',
#   'is',
#   'not',
#   'very',
#   '"people',
#   'oriented".',
#   'however,',
#   'by',
#   'being',
#   'a',
#   'very',
#   'successful',
#   'and',
#   'profitable',
#   'company,',
#   'oracle',
#   'indeed',
#   '"takes',
#   'care"',
#   'of',
#   'its',
#   'people',
#   'more',
#   'than',
#   'adequately.'],
#  ['can',
#   'be',
#   'pretty',
#   'intense,',
#   'especially',
#   'when',
#   'dealing',
#   'w/',
#   'people',
#   'at',
#   'the',
#   'vp',
#   'level.',
#   '',
#   'also',
#   'can',
#   'be',
#   'very',
#   'political.'],
#  ['last',
#   'two',
#   'years',
#   'no',
#   'salary',
#   'raises',
#   'or',
#   'bonuses\r\ncost',
#   'cutting',
#   'periods,',
#   'no',
#   'travel',
#   'unless',
#   'so',
#   'urgent',
#   'and',
#   'so',
#   'holding',
#   'all',
#   'the',
#   'trainings',
#   'online'],
#  ['employees',
#   'are',
#   'just',
#   'cogs',
#   'in',
#   'an',
#   'engine,',
#   'replaceable',
#   'if',
#   'you',
#   'show',
#   'any',
#   'sign',
#   'of',
#   'opposing',
#   'opinions',
#   'to',
#   'the',
#   'borg',
#   'mentality\r\ncustomers',
#   'are',
#   'just',
#   'cash',
#   'providers,',
#   'make',
#   'them',
#   'dependent',
#   'on',
#   'the',
#   'portfolio',
#   'and',
#   'then',
#   'squeeze',
#   'them',
#   'dry\r\nethics',
#   'is',
#   'a',
#   'foreign',
#   'concept'],
#  ['the',
#   'internal',
#   'politics',
#   'is',
#   'an',
#   'important',
#   'factor',
#   'to',
#   'consider.\r\nanother',
#   'con',
#   'is',
#   'that',
#   'there',
#   'is',
#   'little',
#   'feedback',
#   'provided,',
#   'even',
#   'though',
#   'there',
#   'are',
#   'hr',
#   'systems',
#   'in',
#   'place',
#   'to',
#   'do',
#   'so.'],
#  ['there',
#   'are',
#   'too',
#   'many',
#   'politicians',
#   'and',
#   'goofers',
#   'in',
#   'oracle',
#   'who',
#   'have',
#   'been',
#   'there',
#   'for',
#   'long',
#   'and',
#   'only',
#   'god',
#   'knows',
#   'how',
#   'they',
#   'are',
#   'managing',
#   'to',
#   'hold',
#   'on',
#   'to',
#   'their',
#   'jobs',
#   'when',
#   'the',
#   'deserving',
#   'and',
#   'billable',
#   'consultants',
#   'are',
#   'being',
#   'laid',
#   'off',
#   'by',
#   'jerk',
#   'practice',
#   'directors.',
#   '\r\n\r\nsr.',
#   'management',
#   'in',
#   'sydney',
#   'and',
#   'singapore',
#   'are',
#   'aloof',
#   'of',
#   'what',
#   'the',
#   'hell',
#   'is',
#   'happening',
#   'on',
#   'ground',
#   'in',
#   'melbourne.',
#   'all',
#   'they',
#   'care',
#   'about',
#   'is',
#   'their',
#   'freaking',
#   'gross',
#   'margin.',
#   'no',
#   'work',
#   'life',
#   'balance,',
#   'mon-fri,',
#   'sat,',
#   'sun',
#   'are',
#   'the',
#   'same.',
#   'no',
#   'respect',
#   'for',
#   'time',
#   'as',
#   'you',
#   'would',
#   'get',
#   'calls',
#   'at',
#   'odd',
#   'hours',
#   'with',
#   'unrealisitc',
#   'deadlines',
#   'and',
#   'expectations.',
#   'they',
#   'expect',
#   'you',
#   'to',
#   'have',
#   'no',
#   'spouse',
#   'or',
#   'kids',
#   'and',
#   'devote',
#   'all',
#   'your',
#   'time',
#   'to',
#   "larry's",
#   'empire',
#   'in',
#   'contributing',
#   'to',
#   'their',
#   'gross',
#   'margin.',
#   '\r\n\r\nno',
#   'salary',
#   'hikes',
#   'in',
#   '2-3',
#   'years',
#   'due',
#   'to',
#   'the',
#   '(ha',
#   'ha',
#   'ha',
#   '...g',
#   'f..ing',
#   'c;',
#   'global',
#   'financial',
#   'crisis)',
#   'yet',
#   'oracle',
#   'has',
#   'managed',
#   'to',
#   'post',
#   'increasing',
#   'profits',
#   'in',
#   'past',
#   '2-3',
#   'years.'],
#  ['too', 'compartment', 'between', 'the', 'group.'],
#  ['slow', 'growth', 'potential.', 'very', 'political'],
#  ['-',
#   'financial',
#   'package',
#   'is',
#   'not',
#   'that',
#   'competitive.\r\n-',
#   'stressful',
#   'if',
#   'you',
#   'are',
#   'thinking',
#   'about',
#   'sales.\r\n-',
#   'higher',
#   'and',
#   'senior',
#   'management',
#   'posts',
#   'are',
#   'granted',
#   'only',
#   'for',
#   'sales',
#   'people.'],
#  ['-',
#   'financial',
#   'package',
#   'is',
#   'not',
#   'that',
#   'competitive.\r\n-',
#   'stressful',
#   'if',
#   'you',
#   'are',
#   'thinking',
#   'about',
#   'sales.\r\n-',
#   'higher',
#   'and',
#   'senior',
#   'management',
#   'posts',
#   'are',
#   'granted',
#   'only',
#   'for',
#   'sales',
#   'people.'],
#  ['-',
#   'limited',
#   'scope',
#   'in',
#   'a',
#   'given',
#   'role',
#   'because',
#   'of',
#   'large',
#   'organization\r\n-',
#   'limited',
#   'salary',
#   'growth\r\n-',
#   'unstructured',
#   'and',
#   'low',
#   'bonuses'],
#  ['compensation,',
#   'growth',
#   ':',
#   'i',
#   "don't",
#   'see',
#   'apart',
#   'from',
#   'these'],
#  ...]

# %%
#alphabetical
con_words_only_list = []
for review in con_tokenised_list:
    con_words_only = [w for w in review if re.search('^[a-z]+$',w)]
    con_words_only_list.append(con_words_only)

# %%
#stop words
import nltk


from nltk.corpus import stopwords
con_no_stop_words_list = []
stop_list = stopwords.words('english')
# Add extra words to the stop word list 

extra_stop_words = ['company','oracle','pros','cons'] #EDIT THIS PART
stop_list.extend(extra_stop_words)
for review in con_words_only_list:
    con_stop_removed = [w for w in review if w not in stop_list]
    con_no_stop_words_list.append(con_stop_removed)

# %%
#to split conjoined words
import wordninja

import nltk

nltk.download('words')
english_words = set(nltk.corpus.words.words())



con_no_combined_list = []

for review in con_no_stop_words_list :
    new_review = []
    for word in review:
        if word not in english_words:
            word_split_list = wordninja.split(word)
            for w in word_split_list:
                new_review.append(w)
            
        new_review.append(word)
    
    con_no_combined_list.append(new_review)
# Out:
# [nltk_data] Downloading package words to C:\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
print(len(con_no_stop_words_list))
print(len(con_no_combined_list))
# Out:
# 31941
# 31941

# %%
con_adj_removed_list = []
for review in con_no_combined_list:
    review_tagged_words = nltk.pos_tag(review)
#     print(review_tagged_words)
    review_adj_removed = [word for word, pos in review_tagged_words if pos.startswith('N')]
    con_adj_removed_list.append(review_adj_removed)
#     print(con_adj_removed_list[0:30])
len(con_adj_removed_list)
# Out:
# 31941

# %% [markdown]
# <h2>-- END OF DATA CLEANING --

# %%
# !pip install prettytable
# Out:
# Requirement already satisfied: prettytable in c:\users\user\anaconda3\lib\site-packages (3.6.0)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prettytable) (0.2.5)

# %% [markdown]
# # LSA model for Pros

# %%
#alt LSA code ( FINAL)
import gensim
from gensim import corpora, models
from gensim.corpora import Dictionary
from gensim.models.coherencemodel import CoherenceModel
from gensim.matutils import Sparse2Corpus
from prettytable import PrettyTable



# create a dictionary and bag-of-words representation of the reviews
pro_dictionary = corpora.Dictionary(pro_adj_removed_list)
pro_corpus = [pro_dictionary.doc2bow(review) for review in pro_adj_removed_list]

# build the LSA model
pro_lsa_model = models.LsiModel(pro_corpus, num_topics=3, id2word=pro_dictionary)
pro_coherence_model_lsa = CoherenceModel(model=pro_lsa_model, texts=pro_adj_removed_list, dictionary=pro_dictionary, coherence='c_v')
pro_coherence_lsa = pro_coherence_model_lsa.get_coherence()


#code to display words
# get the top words for each topic
pro_topic_words = []
for i, topic in enumerate(pro_lsa_model.show_topics()):
    pro_topic_words.append([word for word, _ in pro_lsa_model.show_topic(i, topn=20)])

# create a dictionary to store the top words for each topic
pro_word_dict = {}
for i in range(len(pro_topic_words)):
    for j, word in enumerate(pro_topic_words[i]):
        if j in pro_word_dict:
            pro_word_dict[j].append(word)
        else:
            pro_word_dict[j] = [word]

# create a PrettyTable and add the topic words as rows
pro_table = PrettyTable(['Topic ' + str(i+1) for i in range(len(pro_topic_words))])
for j in range(len(pro_topic_words[0])):
    row = []
    for i in range(len(pro_topic_words)):
        row.append(pro_word_dict[j][i])
    pro_table.add_row(row)

print(pro_table)
# Out:
# +---------------+---------------+---------------+
# |    Topic 1    |    Topic 2    |    Topic 3    |
# +---------------+---------------+---------------+
# |      work     |    benefits   | opportunities |
# |      life     |      work     |     sales     |
# |    balance    |     sales     |    products   |
# |    benefits   |      life     |    benefits   |
# |      home     | opportunities |      life     |
# | opportunities |     people    |     people    |
# |     people    |    products   |    balance    |
# |     place     |   employees   |      lot      |
# |    culture    |    balance    |    software   |
# |  environment  |     health    |      lots     |
# |     hours     |      lot      |     place     |
# |      team     |      pay      |   employees   |
# |   employees   |   companies   |   resources   |
# |      lot      |   resources   |    product    |
# |   management  |      job      |     career    |
# |     sales     |      lots     |   companies   |
# |      time     |   management  |      job      |
# |    products   |     career    |   technology  |
# |  technologies |  compensation |   management  |
# |    managers   |     things    |      team     |
# +---------------+---------------+---------------+

# %%
print(pro_coherence_lsa)
# Out:
# 0.2920806517392417

# %% [markdown]
# # LSA model for Cons

# %%
#alt LSA code ( FINAL)
import gensim
from gensim import corpora, models
from gensim.corpora import Dictionary
from gensim.models.coherencemodel import CoherenceModel
from gensim.matutils import Sparse2Corpus
from prettytable import PrettyTable



# create a dictionary and bag-of-words representation of the reviews
con_dictionary = corpora.Dictionary(con_adj_removed_list)
con_corpus = [con_dictionary.doc2bow(review) for review in con_adj_removed_list]

# build the LSA model
con_lsa_model = models.LsiModel(con_corpus, num_topics=3, id2word=con_dictionary)
con_coherence_model_lsa = CoherenceModel(model=con_lsa_model, texts=con_adj_removed_list, dictionary=con_dictionary, coherence='c_v')
con_coherence_lsa = con_coherence_model_lsa.get_coherence()


#code to display words
# get the top words for each topic
con_topic_words = []
for i, topic in enumerate(con_lsa_model.show_topics()):
    con_topic_words.append([word for word, _ in con_lsa_model.show_topic(i, topn=20)])

# create a dictionary to store the top words for each topic
con_word_dict = {}
for i in range(len(con_topic_words)):
    for j, word in enumerate(con_topic_words[i]):
        if j in con_word_dict:
            con_word_dict[j].append(word)
        else:
            con_word_dict[j] = [word]

# create a PrettyTable and add the topic words as rows
con_table = PrettyTable(['Topic ' + str(i+1) for i in range(len(con_topic_words))])
for j in range(len(con_topic_words[0])):
    row = []
    for i in range(len(con_topic_words)):
        row.append(con_word_dict[j][i])
    con_table.add_row(row)

print(con_table)
# Out:
# +------------+------------+------------+
# |  Topic 1   |  Topic 2   |  Topic 3   |
# +------------+------------+------------+
# |   sales    |   sales    | employees  |
# |  managers  | employees  |  managers  |
# | employees  |   years    |   years    |
# |   people   |  managers  |   people   |
# | management |    work    |    work    |
# |    work    |   people   |   sales    |
# |   years    | management |   hikes    |
# | customers  |   hikes    | management |
# |    time    | companies  |   things   |
# |  products  |     hr     |  manager   |
# |    team    |    time    |    team    |
# |  manager   |    job     |   months   |
# |    job     | promotions |    time    |
# | companies  |    pay     |  product   |
# |   things   |   things   |    get     |
# |    pay     |  manager   |  products  |
# |  customer  |  employee  | companies  |
# |    reps    |   hours    |    lot     |
# |    year    |    get     |    job     |
# |    lot     |    team    | promotions |
# +------------+------------+------------+

# %%
print(con_coherence_lsa)
# Out:
# 0.6843261339545762
